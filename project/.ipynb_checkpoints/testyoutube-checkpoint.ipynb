# %%
import tensorflow as tf # pip install tensorflow

# %%
import numpy as np ## shift + enter

# %%
filename = 'IMG_1002.JPG'

# %% [markdown]
# #first method to load image

# %%
from IPython.display import Image
Image(filename = 'imgsample.jpeg', width=244, height=244)

# %%
# print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# %%
# %%time 
# import tensorflow.compat.v2 as tf 
# import tensorflow_datasets as tfds 
# tf.enable_v2_behavior() 
# from tensorflow.python.framework.ops import disable_eager_execution 
# disable_eager_execution() 
# (ds_train, ds_test), ds_info = tfds.load( 'mnist', split=['train', 'test'], shuffle_files=True, as_supervised=True, with_info=True, ) 
# def normalize_img(image, label): 
#     """Normalizes images: `uint8` -> `float32`.""" 
#     return tf.cast(image, tf.float32) / 255., label 
# batch_size = 128 
# ds_train = ds_train.map( normalize_img, num_parallel_calls=tf.data.experimental.AUTOTUNE) 
# ds_train = ds_train.cache() 
# ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples) 
# ds_train = ds_train.batch(batch_size) 
# ds_train = ds_train.prefetch(tf.data.experimental.AUTOTUNE) 
# ds_test = ds_test.map( normalize_img, num_parallel_calls=tf.data.experimental.AUTOTUNE) 
# ds_test = ds_test.batch(batch_size) 
# ds_test = ds_test.cache() 
# ds_test = ds_test.prefetch(tf.data.experimental.AUTOTUNE) 
# model = tf.keras.models.Sequential([ 
#     tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu'), 
#     tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'), 
#     tf.keras.layers.MaxPooling2D(pool_size=(2, 2)), 
#     # tf.keras.layers.Dropout(0.25), 
#     tf.keras.layers.Flatten(), 
#     tf.keras.layers.Dense(128, activation='relu'), 
#     # tf.keras.layers.Dropout(0.5), 
#     tf.keras.layers.Dense(10, activation='softmax') ]) 
# model.compile(
#     loss='sparse_categorical_crossentropy', 
#     optimizer=tf.keras.optimizers.Adam(0.001), 
#     metrics=['accuracy'], 
#     )                          
# model.fit( ds_train, 
#           epochs=12, 
#           validation_data=ds_test, 
#          )

# %% [markdown]
# #Second method to loadd an image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
##first method is better

# %% [markdown]
# ##third method to load an image

# %%
import cv2 ##pip install opencv-python  ##most famously used image task

# %%
imgg = cv2.imread(filename)

# %%
plt.imshow(imgg)

# %%
imgg = cv2.resize(imgg, (224,224))

# %%
plt.imshow(imgg)

# %%
plt.imshow(cv2.cvtColor(imgg, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## fourth method to load image

# %%
from PIL import Image ## pip install Pillow

# %%
im = Image.open(filename) ## PIL

# %%
im = im.resize((224,224))

# %%
plt.imshow(im)

# %% [markdown]
# ##Lets load the deep learning model

# %%
mobile = tf.keras.applications.mobilenet.MobileNet() ## deep learning model wrights -pre-trained
# Out:
# 2022-03-28 09:59:24.805607: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-03-28 09:59:25.712704: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-03-28 09:59:26.129637: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
## Creating a model
## Training a model
## test or validate
#Predict

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2()
# Out:
# 2022-03-28 09:59:28.532439: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-03-28 09:59:29.644377: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-03-28 09:59:30.359139: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
##mobile = tf.keras.applications.mobilenet_v3

# %% [markdown]
# ## Pre-processing of the image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img, axis=0) ##need fourth dimension
final_image=tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_image)
# Out:
# 2022-03-28 09:59:31.612747: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n02123045', 'tabby', 0.13495912), ('n02123597', 'Siamese_cat', 0.09623395), ('n02123394', 'Persian_cat', 0.031993035), ('n02124075', 'Egyptian_cat', 0.026338171), ('n02086079', 'Pekinese', 0.023423174)]]

# %%
plt.imshow(img)

# %%
predictions = mobile.predict(final_image)

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n02123045', 'tabby', 0.13495912), ('n02123597', 'Siamese_cat', 0.09623395), ('n02123394', 'Persian_cat', 0.031993035), ('n02124075', 'Egyptian_cat', 0.026338171), ('n02086079', 'Pekinese', 0.023423174)]]

# %%
anyone = tf.keras.applications.
# Out:
#   Input In [163]
#     anyone = tf.keras.applications.
#                                    ^
# SyntaxError: invalid syntax
