# %%
##!pip install cmake

# %%
##!pip install opencv-contrib-python dlib

# %%
import cv2, dlib, sys
import numpy as np

# %%
scaler = 0.3
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor()
cap = cv2.VideoCapture('we.mov')

# %%
# ret, img = cap.read()
# img = cv2.resize(img, 
#                  (int(img.shape[1] * scaler), 
#                   int(img.shape[0] * scaler))
#                 )

# %%
#img

# %%
# faces = detector(img)
# faces

# %%
while True:
    ret, img = cap.read()
    if not ret:
        break
        
    img = cv2.resize(img, 
                     (int(img.shape[1] * scaler), 
                      int(img.shape[0] * scaler)))
    ori = img.copy()
    
    faces = detector(img)
#     print(faces)
#     face = faces[0]
#     print(face)
    
    for face in faces:
        dlib_shape = predictor(img, face)
        print(dlib_shape)
        print(dlib_shape.parts())

    #     shape_2d = np.array([[p.x, p.y] for p in dlib_shape.parts()])

    #     top_left = np.min(shape_2d, axis=0)
    #     bottom_right = np.max(shape_2d, axis=1)

        img = cv2.rectangle(img, 
                            pt1 = (face.left(), face.top()), 
                            pt2 = (face.right(), face.bottom()),
                            color=(255,255,255),
                            thickness = 2,
                            lineType=cv2.LINE_AA)

#     for s in shape_2d:
#         cv2.circle(img, 
#                    center=tuple([100, 200]), 
#                    radius=1, 
#                    color=(255, 255, 255),
#                    thickness=2,
#                    lineType=cv2.LINE_AA)
    
#     cv2.circle(img, 
#                    center=tuple([160, 237]), 
#                    radius=1, 
#                    color=(255, 255, 255),
#                    thickness=2,
#                    lineType=cv2.LINE_AA)
    
    cv2.imshow('img', img)
    cv2.waitKey(1)
# Out:
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
# points[]
# ...
