# %%
area = {
    11:'서울특별시',
    11230:'서울특별시 강남구',
    11250:'서울특별시 강동구',
    11090:'서울특별시 강북구',
    11160:'서울특별시 강서구',
    11210:'서울특별시 관악구',
    11050:'서울특별시 광진구',
    11170:'서울특별시 구로구',
    11180:'서울특별시 금천구',
    11110:'서울특별시 노원구',
    11100:'서울특별시 도봉구',
    11060:'서울특별시 동대문구',
    11200:'서울특별시 동작구',
    11140:'서울특별시 마포구',
    11130:'서울특별시 서대문구',
    11220:'서울특별시 서초구',
    11040:'서울특별시 성동구',
    11080:'서울특별시 성북구',
    11240:'서울특별시 송파구',
    11150:'서울특별시 양천구',
    11190:'서울특별시 영등포구',
    11030:'서울특별시 용산구',
    11120:'서울특별시 은평구',
    11010:'서울특별시 종로구',
    11020:'서울특별시 중구',
    11070:'서울특별시 중랑구',
    21:'부산광역시',
    21120:'부산광역시 강서구',
    21110:'부산광역시 금정구',
    21070:'부산광역시 남구',
    21030:'부산광역시 동구',
    21060:'부산광역시 동래구',
    21050:'부산광역시 부산진구',
    21080:'부산광역시 북구',
    21150:'부산광역시 사상구',
    21100:'부산광역시 사하구',
    21020:'부산광역시 서구',
    21140:'부산광역시 수영구',
    21130:'부산광역시 연제구',
    21040:'부산광역시 영도구',
    21010:'부산광역시 중구',
    21090:'부산광역시 해운대구',
    21310:'부산광역시 기장군',
    22:'대구광역시',
    22040:'대구광역시 남구',
    22070:'대구광역시 달서구',
    22020:'대구광역시 동구',
    22050:'대구광역시 북구',
    22030:'대구광역시 서구',
    22060:'대구광역시 수성구',
    22010:'대구광역시 중구',
    22310:'대구광역시 달성군',
    23:'인천광역시',
    23070:'인천광역시 계양구',
    23030:'인천광역시 남구',
    23050:'인천광역시 남동구',
    23020:'인천광역시 동구',
    23060:'인천광역시 부평구',
    23080:'인천광역시 서구',
    23040:'인천광역시 연수구',
    23010:'인천광역시 중구',
    23310:'인천광역시 강화군',
    23320:'인천광역시 옹진군',
    25:'대전광역시',
    25050:'대전광역시 대덕구',
    25010:'대전광역시 동구',
    25030:'대전광역시 서구',
    25040:'대전광역시 유성구',
    25020:'대전광역시 중구',
    29010:'세종특별자치시 세종시',
    24:'광주광역시',
    24050:'광주광역시 광산구',
    24030:'광주광역시 남구',
    24010:'광주광역시 동구',
    24040:'광주광역시 북구',
    24020:'광주광역시 서구',
    26:'울산광역시',
    26020:'울산광역시 남구',
    26030:'울산광역시 동구',
    26040:'울산광역시 북구',
    26010:'산광역시 중구',
    26310:'울산광역시 울주군',
    31:'경기도',
    31100:'경기도 고양시',
    31110:'경기도 과천시',
    31060:'경기도 광명시',
    31250:'경기도 광주시',
    31120:'경기도 구리시',
    31160:'경기도 군포시',
    31230:'경기도 김포시',
    31130:'경기도 남양주시',
    31080:'경기도 동두천시',
    31050:'경기도 부천시',
    31020:'경기도 성남시',
    31010:'경기도 수원시',
    31150:'경기도 시흥시',
    31090:'경기도 안산시',
    31220:'경기도 안성시',
    31040:'경기도 안양시',
    31260:'경기도 양주시',
    31140:'경기도 오산시',
    31190:'경기도 용인시',
    31170:'경기도 의왕시',
    31030:'경기도 의정부시',
    31210:'경기도 이천시',
    31200:'경기도 파주시',
    31070:'경기도 평택시',
    31270:'경기도 포천시',
    31180:'경기도 하남시',
    31240:'경기도 화성시',
    31370:'경기도 가평군',
    31380:'경기도 양평군',
    31280:'경기도 여주시',
    31350:'경기도 연천군',
    32:'강원도',
    32030:'강원도 강릉시',
    32040:'강원도 동해시',
    32070:'강원도 삼척시',
    32060:'강원도 속초시',
    32020:'강원도 원주시',
    32010:'강원도 춘천시',
    32050:'강원도 태백시',
    32400:'강원도 고성군',
    32380:'강원도 양구군',
    32410:'강원도 양양군',
    32330:'강원도 영월군',
    32390:'강원도 인제군',
    32350:'강원도 정선군',
    32360:'강원도 철원군',
    32340:'강원도 평창군',
    32310:'강원도 홍천군',
    32370:'강원도 화천군',
    32320:'강원도 횡성군',
    33:'충청북도',
    33030:'충청북도 제천시',
    33040:'충청북도 청주시',
    33020:'청북도 충주시',
    33360:'충청북도 괴산군',
    33380:'충청북도 단양군',
    33320:'충청북도 보은군',
    33340:'청북도 영동군',
    33330:'충청북도 옥천군',
    33370:'충청북도 음성군',
    33390:'충청북도 증평군',
    33350:'충청북도 진천군',
    34:'충청남도',
    34070:'충청남도 계룡시',
    34020:'충청남도 공주시',
    34060:'충청남도 논산시',
    34030:'충청남도 보령시',
    34050:'충청남도 서산시',
    34040:'충청남도 아산시',
    34010:'충청남도 천안시',
    34310:'충청남도 금산군',
    34080:'청남도 당진시',
    34330:'청남도 부여군',
    34340:'충청남도 서천군',
    34370:'충청남도 예산군',
    34350:'충청남도 청양군',
    34380:'충청남도 태안군',
    34360:'청남도 홍성군',
    37:'경상북도',
    37100:'경상북도 경산시',
    37020:'경상북도 경주시',
    37050:'경상북도 구미시',
    37030:'경상북도 김천시',
    37090:'경상북도 문경시',
    37080:'경상북도 상주시',
    37040:'상북도 안동시',
    37060:'상북도 영주시',
    37070:'경상북도 영천시',
    37010:'경상북도 포항시',
    37370:'경상북도 고령군',
    37310:'경상북도 군위군',
    37410:'상북도 봉화군',
    37380:'경상북도 성주군',
    37350:'경상북도 영덕군',
    37340:'경상북도 영양군',
    37400:'상북도 예천군',
    37430:'경상북도 울릉군',
    37420:'경상북도 울진군',
    37320:'경상북도 의성군',
    37360:'경상북도 청도군',
    37330:'경상북도 청송군',
    37390:'경상북도 칠곡군',
    38:'경상남도',		
    38090:'상남도 거제시',
    38070:'경상남도 김해시',
    38080:'경상남도 밀양시',
    38060:'경상남도 사천시',
    38100:'경상남도 양산시',
    38030:'경상남도 진주시',
    38110:'경상남도 창원시',
    38050:'경상남도 통영시',
    38390:'경상남도 거창군',
    38340:'경상남도 고성군',
    38350:'경상남도 남해군',
    38370:'경상남도 산청군',
    38310:'경상남도 의령군',
    38330:'경상남도 창녕군',
    38360:'상남도 하동군',
    38320:'경상남도 함안군',
    38380:'경상남도 함양군',
    38400:'경상남도 합천군',
    35:'전라북도',
    35020:'전라북도 군산시',
    35060:'전라북도 김제시',
    35050:'전라북도 남원시',
    35030:'전라북도 익산시',
    35010:'라북도 전주시',
    35040:'전라북도 정읍시',
    35370:'전라북도 고창군',
    35330:'전라북도 무주군',
    35380:'전라북도 부안군',
    35360:'전라북도 순창군',
    35310:'전라북도 완주군',
    35350:'전라북도 임실군',
    35340:'전라북도 장수군',
    35320:'전라북도 진안군',
    36:'전라남도',
    36060:'전라남도 광양시',
    36040:'라남도 나주시',
    36010:'전라남도 목포시',
    36030:'전라남도 순천시',
    36020:'전라남도 여수시',
    36390:'전라남도 강진군',
    36350:'전라남도 고흥군',
    36320:'전라남도 곡성군',
    36330:'전라남도 구례군',
    36310:'전라남도 담양군',
    36420:'전라남도 무안군',
    36360:'전라남도 보성군',
    36480:'전라남도 신안군',
    36440:'전라남도 영광군',
    36410:'전라남도 영암군',
    36460:'전라남도 완도군',
    36450:'전라남도 장성군',
    36380:'전라남도 장흥군',
    36470:'라남도 진도군',
    36430:'전라남도 함평군',
    36400:'전라남도 해남군',
    36370:'전라남도 화순군',
    39:'제주특별자치도',
    39010:'제주특별자치도 제주시',
    39020:'제주특별자치도 서귀포시',


    ##추가
    31320:'경기도 여주시', ## 여주군에서 여주시로 바뀜
    33010:'충청북도 청주시', ##청주군에서 청주시로 바뀜 
    33310:'충청북도 청주시', ##청원군 청주시로 통합
    34320:'세종특별자치시 세종시' ## 충남연기군 세종특별로 통합
    
       
       }

# %%
area
# Out:
# {11: '서울특별시',
#  11230: '서울특별시 강남구',
#  11250: '서울특별시 강동구',
#  11090: '서울특별시 강북구',
#  11160: '서울특별시 강서구',
#  11210: '서울특별시 관악구',
#  11050: '서울특별시 광진구',
#  11170: '서울특별시 구로구',
#  11180: '서울특별시 금천구',
#  11110: '서울특별시 노원구',
#  11100: '서울특별시 도봉구',
#  11060: '서울특별시 동대문구',
#  11200: '서울특별시 동작구',
#  11140: '서울특별시 마포구',
#  11130: '서울특별시 서대문구',
#  11220: '서울특별시 서초구',
#  11040: '서울특별시 성동구',
#  11080: '서울특별시 성북구',
#  11240: '서울특별시 송파구',
#  11150: '서울특별시 양천구',
#  11190: '서울특별시 영등포구',
#  11030: '서울특별시 용산구',
#  11120: '서울특별시 은평구',
#  11010: '서울특별시 종로구',
#  11020: '서울특별시 중구',
#  11070: '서울특별시 중랑구',
#  21: '부산광역시',
#  21120: '부산광역시 강서구',
#  21110: '부산광역시 금정구',
#  21070: '부산광역시 남구',
#  21030: '부산광역시 동구',
#  21060: '부산광역시 동래구',
#  21050: '부산광역시 부산진구',
#  21080: '부산광역시 북구',
#  21150: '부산광역시 사상구',
#  21100: '부산광역시 사하구',
#  21020: '부산광역시 서구',
#  21140: '부산광역시 수영구',
#  21130: '부산광역시 연제구',
#  21040: '부산광역시 영도구',
#  21010: '부산광역시 중구',
#  21090: '부산광역시 해운대구',
#  21310: '부산광역시 기장군',
#  22: '대구광역시',
# ...

# %%
import pandas as pd

# %%
df_raw = pd.read_csv('2021_여행지데이터.csv')
df_raw
# Out:
#                         id lclas mlsfc    id_poi       poi_nm branch_nm  \
# 0      KCLANPO21N000000001    장소   관광지    549380     구절리역(폐역)       NaN
# 1      KCLANPO21N000000002    장소   관광지    808576        만년저수지       NaN
# 2      KCLANPO21N000000003    장소   관광지    808705        대암소류지       NaN
# 3      KCLANPO21N000000004    장소   관광지    808746        대양소류지       NaN
# 4      KCLANPO21N000000005    장소   관광지    809458        대장저수지       NaN
# ...                    ...   ...   ...       ...          ...       ...
# 38435  KCLANPO21N000038436    장소   관광지  21948792      쌍계사수목장림       NaN
# 38436  KCLANPO21N000038437    장소   관광지  21960254  파주눈내리는초리골축제       NaN
# 38437  KCLANPO21N000038438    장소   관광지  22051690        토리딸기팜       NaN
# 38438  KCLANPO21N000038439    장소   관광지  22113578      고성만해지개길       NaN
# 38439  KCLANPO21N000038440    장소   관광지  22146369       청파관광농원       NaN
#
#        sub_nm  mcate_cd   mcate_nm           pnu  ...         rd_cd  rd_nm  \
# ...

# %%
df_raw.columns
# Out:
# Index(['id', 'lclas', 'mlsfc', 'id_poi', 'poi_nm', 'branch_nm', 'sub_nm',
#        'mcate_cd', 'mcate_nm', 'pnu', 'sido_nm', 'sgg_nm', 'bemd_nm', 'ri_nm',
#        'beonji', 'badm_cd', 'hadm_cd', 'rd_cd', 'rd_nm', 'bld_num', 'x', 'y',
#        'grid_cd', 'lst_updt_dt', 'data_orgn', 'FILE_NAME', 'base_ymd'],
#       dtype='object')

# %%
df = df_raw

# %%
use_col = ['poi_nm', 'sido_nm', 'sgg_nm', 'target']

# %%
list1 = ['지역호수/저수지', '지역사찰', '일반관광지', '대형호수/저수지', '숲']
list2 = ['폭포/계곡', '관광농원/허브마을', '해수욕장', '일반유원지/일반놀이공원', '테마공원/대형놀이공원', '아쿠아리움/대형수족관', '카지노', '파라다이스카지노', '세븐럭카지노']
list3 = ['토속/특산물/기념품매장', '먹거리/패션거리']
list4 = ['지역축제', '서원/향교/서당', '휴양림/수목원', '유명사찰', '유명관광지', '식물원', '동물원']

# %%
for index in df.index:
    if df.loc[index,'mcate_nm'] in list1:
        df.loc[index,'target']='힐링, 호캉스'
    elif df.loc[index,'mcate_nm'] in list2:
        df.loc[index,'target']='액티비티'
    elif df.loc[index,'mcate_nm'] in list3:
        df.loc[index,'target']='식도락, 맛집투어'
    elif df.loc[index,'mcate_nm'] in list4:
        df.loc[index,'target']='축제, 관광'

# %%
df = df[use_col]
df
# Out:
#             poi_nm sido_nm   sgg_nm     target
# 0         구절리역(폐역)     강원도      정선군    힐링, 호캉스
# 1            만년저수지    전라남도      해남군    힐링, 호캉스
# 2            대암소류지    경상남도      진주시    힐링, 호캉스
# 3            대양소류지    충청북도      보은군    힐링, 호캉스
# 4            대장저수지    전라남도      신안군    힐링, 호캉스
# ...            ...     ...      ...        ...
# 38435      쌍계사수목장림     경기도  안산시 단원구     축제, 관광
# 38436  파주눈내리는초리골축제     경기도      파주시     축제, 관광
# 38437        토리딸기팜    경상남도  창원시 의창구       액티비티
# 38438      고성만해지개길    경상남도      고성군  식도락, 맛집투어
# 38439       청파관광농원    경상북도      성주군       액티비티
#
# [38440 rows x 4 columns]

# %%
df['sido_nm'].value_counts()
# Out:
# 경상남도       5612
# 경상북도       5180
# 전라남도       4817
# 경기도        4037
# 전라북도       3138
# 강원도        2697
# 충청남도       2409
# 서울특별시      2242
# 충청북도       2089
# 부산광역시      1430
# 제주특별자치도    1185
# 대구광역시      1029
# 울산광역시       835
# 인천광역시       630
# 광주광역시       495
# 대전광역시       454
# 세종특별자치시     161
# Name: sido_nm, dtype: int64

# %%
df['sgg_nm'].value_counts()
# Out:
# 제주시    680
# 중구     660
# 경주시    643
# 동구     588
# 영천시    559
#       ...
# 양천구     34
# 금천구     33
# 오산시     30
# 군포시     20
# 계룡시     19
# Name: sgg_nm, Length: 207, dtype: int64

# %%
import re
for index in df.index:
    a = df.loc[index, 'sgg_nm']
    a = re.sub('\s.*','',a)
    df.loc[index, 'sgg_nm'] = a
# Out:
# /var/folders/3m/knb96f9s4xg2t2gcrl96r6jh0000gn/T/ipykernel_85443/2457214293.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[index, 'sgg_nm'] = a

# %%
df.loc[1,'sgg_nm']
# Out:
# '해남군'

# %%
import re
test = '창원시성산구'
test = re.sub('\s.*','',test)

# %%
test
# Out:
# '창원시성산구'

# %%
df.loc[1, 'sgg_nm']

# %%
df['area'] = df['sido_nm']+ ' ' + df['sgg_nm']
# Out:
# /var/folders/3m/knb96f9s4xg2t2gcrl96r6jh0000gn/T/ipykernel_85443/1122367037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area'] = df['sido_nm']+ ' ' + df['sgg_nm']

# %%
df
# Out:
#             poi_nm sido_nm sgg_nm     target      area
# 0         구절리역(폐역)     강원도    정선군    힐링, 호캉스   강원도 정선군
# 1            만년저수지    전라남도    해남군    힐링, 호캉스  전라남도 해남군
# 2            대암소류지    경상남도    진주시    힐링, 호캉스  경상남도 진주시
# 3            대양소류지    충청북도    보은군    힐링, 호캉스  충청북도 보은군
# 4            대장저수지    전라남도    신안군    힐링, 호캉스  전라남도 신안군
# ...            ...     ...    ...        ...       ...
# 38435      쌍계사수목장림     경기도    안산시     축제, 관광   경기도 안산시
# 38436  파주눈내리는초리골축제     경기도    파주시     축제, 관광   경기도 파주시
# 38437        토리딸기팜    경상남도    창원시       액티비티  경상남도 창원시
# 38438      고성만해지개길    경상남도    고성군  식도락, 맛집투어  경상남도 고성군
# 38439       청파관광농원    경상북도    성주군       액티비티  경상북도 성주군
#
# [38440 rows x 5 columns]

# %%
df = df[['poi_nm', 'area', 'target']]
df
# Out:
#             poi_nm      area     target
# 0         구절리역(폐역)   강원도 정선군    힐링, 호캉스
# 1            만년저수지  전라남도 해남군    힐링, 호캉스
# 2            대암소류지  경상남도 진주시    힐링, 호캉스
# 3            대양소류지  충청북도 보은군    힐링, 호캉스
# 4            대장저수지  전라남도 신안군    힐링, 호캉스
# ...            ...       ...        ...
# 38435      쌍계사수목장림   경기도 안산시     축제, 관광
# 38436  파주눈내리는초리골축제   경기도 파주시     축제, 관광
# 38437        토리딸기팜  경상남도 창원시       액티비티
# 38438      고성만해지개길  경상남도 고성군  식도락, 맛집투어
# 38439       청파관광농원  경상북도 성주군       액티비티
#
# [38440 rows x 3 columns]

# %%
df = df.rename(columns=
               {
                   'poi_nm':'place_info'
               })
df
# Out:
#         place_info      area     target
# 0         구절리역(폐역)   강원도 정선군    힐링, 호캉스
# 1            만년저수지  전라남도 해남군    힐링, 호캉스
# 2            대암소류지  경상남도 진주시    힐링, 호캉스
# 3            대양소류지  충청북도 보은군    힐링, 호캉스
# 4            대장저수지  전라남도 신안군    힐링, 호캉스
# ...            ...       ...        ...
# 38435      쌍계사수목장림   경기도 안산시     축제, 관광
# 38436  파주눈내리는초리골축제   경기도 파주시     축제, 관광
# 38437        토리딸기팜  경상남도 창원시       액티비티
# 38438      고성만해지개길  경상남도 고성군  식도락, 맛집투어
# 38439       청파관광농원  경상북도 성주군       액티비티
#
# [38440 rows x 3 columns]

# %%
df.to_csv('place_trip.csv')
