# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/Users/syshin/Downloads/2017³â ±¹¹Î¿©Çà½ÇÅÂÁ¶»ç µ¥ÀÌÅÍ 2/2. 개인_국내관광+해외관광/2. 개인_국내관광+해외관광_방문지.xlsx')
df
# Out:
#          hid      PID  type1  type2  Month      M_ID   q6_1  q6_1_1  q6_1_2  \
# 0      10001  1000101      1    2.0    8.0  115439.0  931.0    10.0     NaN
# 1      10001  1000102      1    2.0   12.0  115441.0  931.0   260.0     NaN
# 2      10002  1000203      1    2.0   10.0  123587.0  932.0    30.0     NaN
# 3      10002  1000201      3    NaN    NaN       NaN    NaN     NaN     NaN
# 4      10002  1000202      3    NaN    NaN       NaN    NaN     NaN     NaN
# ...      ...      ...    ...    ...    ...       ...    ...     ...     ...
# 11300  15392  1539201      3    NaN    NaN       NaN    NaN     NaN     NaN
# 11301  15395  1539502      1    1.0    4.0  109471.0  938.0    50.0     NaN
# 11302  15395  1539501      3    NaN    NaN       NaN    NaN     NaN     NaN
# 11303  15399  1539901      3    NaN    NaN       NaN    NaN     NaN     NaN
# 11304  15399  1539902      3    NaN    NaN       NaN    NaN     NaN     NaN
#
# ...

# %%
df.columns
# Out:
# Index(['hid', 'PID', 'type1', 'type2', 'Month', 'M_ID', 'q6_1', 'q6_1_1',
#        'q6_1_2', 'q6_1_3', 'q6_1_4', 'q6_1_5', 'q6_1_6', 'q6_1_7', 'q6_1_8',
#        'q6_2', 'q6_3_a', 'q6_3_b', 'q6_3_c', 'q6_4', 'q6_5_1', 'q6_5_2',
#        'q6_5_3', 'q6_5_4', 'q6_5_5', 'q6_5_6', 'q6_5_7', 'q6_5_8', 'q6_5_9',
#        'q6_5_10', 'q6_5_11', 'q6_5_12', 'q6_5_13', 'q6_5_1a', 'q6_5_2a',
#        'q6_5_3a', 'q6_5_4a', 'q6_5_5a', 'q6_5_6a', 'q6_5_7a', 'q6_5_8a',
#        'q6_5_9a', 'q6_5_10a', 'q6_5_11a', 'q6_5_12a', 'q6_5_13a', 'q6_6_1',
#        'q6_6_2', 'q6_6_3', 'q6_6_4', 'q6_6_5', 'q6_6_6', 'q6_6_7', 'q6_6_8',
#        'q6_6_9', 'q6_6_10', 'q6_6_11', 'q6_6_12', 'q6_6_13', 'q6_6_14',
#        'q6_6_15', 'q6_6_16', 'q6_6_17', 'q6_6_18', 'q6_6_19', 'q6_6_20',
#        'q6_6_21', 'q6_7', 'q6_8', 'q6_9', 'q7_2', 'WT'],
#       dtype='object')

# %%
use_col = ['type1', 'PID', 'q6_7', 'q6_1', 'q6_1_1']

# %%
df = df[use_col]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11305 entries, 0 to 11304
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   type1   11305 non-null  int64
#  1   PID     11305 non-null  int64
#  2   q6_7    7764 non-null   float64
#  3   q6_1    7764 non-null   float64
#  4   q6_1_1  7764 non-null   float64
# dtypes: float64(3), int64(2)
# memory usage: 441.7 KB

# %%
df = df[df['type1']==1]

# %%
df.dropna(axis=0, how='any', subset=use_col, inplace=True)
# Out:
# /var/folders/3m/knb96f9s4xg2t2gcrl96r6jh0000gn/T/ipykernel_86021/273042046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis=0, how='any', subset=use_col, inplace=True)

# %%
df = df.astype(
    {
        'q6_1':'int',
        'q6_1_1':'int',
    })

# %%
for index in df.index:
    df.loc[index,'area'] = str(df.loc[index, 'q6_1']).lstrip('9') + str(df.loc[index,'q6_1_1']).zfill(3)
df
# Out:
#        type1      PID  q6_7  q6_1  q6_1_1   area
# 0          1  1000101   4.0   931      10  31010
# 1          1  1000102   4.0   931     260  31260
# 2          1  1000203   4.0   932      30  32030
# 5          1  1000303   4.0   923      40  23040
# 7          1  1000401   4.0   932      60  32060
# ...      ...      ...   ...   ...     ...    ...
# 11296      1  1539203   4.0   921      50  21050
# 11297      1  1539203   4.0   921      50  21050
# 11298      1  1539202   5.0   935      10  35010
# 11299      1  1539203   3.0   938     310  38310
# 11301      1  1539502   4.0   938      50  38050
#
# [6924 rows x 6 columns]

# %%
type(str(df.loc[1,'q6_1']).lstrip('9'))
# Out:
# str

# %%
use_col
# Out:
# ['type1', 'PID', 'q6_7', 'q6_1', 'q6_1_1']

# %%
df = df[['PID', 'q6_7', 'area']]
df
# Out:
#            PID  q6_7   area
# 0      1000101   4.0  31010
# 1      1000102   4.0  31260
# 2      1000203   4.0  32030
# 5      1000303   4.0  23040
# 7      1000401   4.0  32060
# ...        ...   ...    ...
# 11296  1539203   4.0  21050
# 11297  1539203   4.0  21050
# 11298  1539202   5.0  35010
# 11299  1539203   3.0  38310
# 11301  1539502   4.0  38050
#
# [6924 rows x 3 columns]

# %%
df = df.rename(columns=
          {
              'PID':'userID',
              'q6_7':'rating',
          })

# %%
df
# Out:
#         userID  rating   area
# 0      1000101     4.0  31010
# 1      1000102     4.0  31260
# 2      1000203     4.0  32030
# 5      1000303     4.0  23040
# 7      1000401     4.0  32060
# ...        ...     ...    ...
# 11296  1539203     4.0  21050
# 11297  1539203     4.0  21050
# 11298  1539202     5.0  35010
# 11299  1539203     3.0  38310
# 11301  1539502     4.0  38050
#
# [6924 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6924 entries, 0 to 11301
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userID  6924 non-null   int64
#  1   rating  6924 non-null   float64
#  2   area    6924 non-null   object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 474.4+ KB

# %%
df['area'] = df['area'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6924 entries, 0 to 11301
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userID  6924 non-null   int64
#  1   rating  6924 non-null   float64
#  2   area    6924 non-null   int64
# dtypes: float64(1), int64(2)
# memory usage: 474.4 KB

# %%
area = {11:'서울특별시',	
11230:'서울특별시 강남구',
11250:'서울특별시 강동구',
11090:'서울특별시 강북구',
11160:'서울특별시 강서구',
11210:'서울특별시 관악구',
11050:'서울특별시 광진구',
11170:'서울특별시 구로구',
11180:'서울특별시 금천구',
11110:'서울특별시 노원구',
11100:'서울특별시 도봉구',
11060:'서울특별시 동대문구',
11200:'서울특별시 동작구',
11140:'서울특별시 마포구',
11130:'서울특별시 서대문구',
11220:'서울특별시 서초구',
11040:'서울특별시 성동구',
11080:'서울특별시 성북구',
11240:'서울특별시 송파구',
11150:'서울특별시 양천구',
11190:'서울특별시 영등포구',
11030:'서울특별시 용산구',
11120:'서울특별시 은평구',
11010:'서울특별시 종로구',
11020:'서울특별시 중구',
11070:'서울특별시 중랑구',
21:'부산광역시',
21120:'부산광역시 강서구',
21110:'부산광역시 금정구',
21070:'부산광역시 남구',
33390:'충청북도 증평군',
33350:'충청북도 진천군',
34:'충청남도',
34070:'충청남도 계룡시',
34020:'충청남도 공주시',
34060:'충청남도 논산시',
34030:'충청남도 보령시',
34050:'충청남도 서산시',
34040:'충청남도 아산시',
34010:'충청남도 천안시',
34310:'충청남도 금산군',
34080:'청남도 당진시',
34330:'청남도 부여군',
34340:'충청남도 서천군',
34370:'충청남도 예산군',
34350:'충청남도 청양군',
34380:'충청남도 태안군',
34360:'청남도 홍성군',
37:'경상북도',
37100:'경상북도 경산시',
37020:'경상북도 경주시',
37050:'경상북도 구미시',
37030:'경상북도 김천시',
37090:'경상북도 문경시',
37080:'경상북도 상주시',
37040:'상북도 안동시',
37060:'상북도 영주시',
37070:'경상북도 영천시',
37010:'경상북도 포항시',
37370:'경상북도 고령군',
37310:'경상북도 군위군',
37410:'상북도 봉화군',
37380:'경상북도 성주군',
37350:'경상북도 영덕군',
37340:'경상북도 영양군',
37400:'상북도 예천군',
37430:'경상북도 울릉군',
37420:'경상북도 울진군',
37320:'경상북도 의성군',
37360:'경상북도 청도군',
37330:'경상북도 청송군',
37390:'경상북도 칠곡군',
38:'경상남도',		
38090:'상남도 거제시',
38070:'경상남도 김해시',
38080:'경상남도 밀양시',
38060:'경상남도 사천시',
38100:'경상남도 양산시',
38030:'경상남도 진주시',
38110:'경상남도 창원시',
38050:'경상남도 통영시',
38390:'경상남도 거창군',
38340:'경상남도 고성군',
38350:'경상남도 남해군',
38370:'경상남도 산청군',
38310:'경상남도 의령군',
38330:'경상남도 창녕군',
38360:'상남도 하동군',
38320:'경상남도 함안군',
38380:'경상남도 함양군',
38400:'경상남도 합천군',
35:'전라북도',
35020:'전라북도 군산시',
35060:'전라북도 김제시',
35050:'전라북도 남원시',
35030:'전라북도 익산시',
35010:'라북도 전주시',
35040:'전라북도 정읍시',
35370:'전라북도 고창군',
35330:'전라북도 무주군',
35380:'전라북도 부안군',
35360:'전라북도 순창군',
35310:'전라북도 완주군',
35350:'전라북도 임실군',
35340:'전라북도 장수군',
35320:'전라북도 진안군',
36:'전라남도',
36060:'전라남도 광양시',
36040:'라남도 나주시',
36010:'전라남도 목포시',
36030:'전라남도 순천시',
36020:'전라남도 여수시',
36390:'전라남도 강진군',
36350:'전라남도 고흥군',
36320:'전라남도 곡성군',
36330:'전라남도 구례군',
36310:'전라남도 담양군',
36420:'전라남도 무안군',
36360:'전라남도 보성군',
36480:'전라남도 신안군',
36440:'전라남도 영광군',
36410:'전라남도 영암군',
36460:'전라남도 완도군',
36450:'전라남도 장성군',
36380:'전라남도 장흥군',
36470:'라남도 진도군',
36430:'전라남도 함평군',
36400:'전라남도 해남군',
36370:'전라남도 화순군',
39:'제주특별자치도',
39010:'제주특별자치도 제주시',
39020:'제주특별자치도 서귀포시'}

# %%
for index in df.index:
    df.loc[index,'area'] = area[df.loc[index,'area']]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
#       1 for index in df.index:
# ----> 2     df.loc[index,'area'] = area[df.loc[index,'area']]
#       3 df
#
# KeyError: 31320

# %%
df.to_csv('ratings_trip.csv')
