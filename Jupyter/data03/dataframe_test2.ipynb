# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("../csv-data/concat_1.csv")

# %%
df2 = pd.read_csv("../csv-data/concat_2.csv")

# %%
df3 = pd.read_csv("../csv-data/concat_3.csv")

# %%
df11 = pd.read_csv("../csv-data/concat_11.csv")

# %%
df22 = pd.read_csv("../csv-data/concat_22.csv")

# %%
df33 = pd.read_csv("../csv-data/concat_33.csv")

# %%
row_concat = pd.concat([df1, df2, df3], ignore_index=True)
row_concat
# Out:
#       A    B    C    D
# 0    a0   b0   c0   d0
# 1    a1   b1   c1   d1
# 2    a2   b2   c2   d2
# 3    a3   b3   c3   d3
# 4    a4   b4   c4   d4
# 5    a5   b5   c5   d5
# 6    a6   b6   c6   d6
# 7    a7   b7   c7   d7
# 8    a8   b8   c8   d8
# 9    a9   b9   c9   d9
# 10  a10  b10  c10  d10
# 11  a11  b11  c11  d11

# %%
row_concat2 = pd.concat([df11,df22,df33], ignore_index=True)
row_concat2 #outer join, pd.concat(join='outer')
# Out:
# C:\Users\hi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#       A    B    C    D    E    F    G    H
# 0    a0   b0   c0   d0  NaN  NaN  NaN  NaN
# 1    a1   b1   c1   d1  NaN  NaN  NaN  NaN
# 2    a2   b2   c2   d2  NaN  NaN  NaN  NaN
# 3    a3   b3   c3   d3  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   a4   b4   c4   d4
# 5   NaN  NaN  NaN  NaN   a5   b5   c5   d5
# 6   NaN  NaN  NaN  NaN   a6   b6   c6   d6
# 7   NaN  NaN  NaN  NaN   a7   b7   c7   d7
# 8    a1  NaN   b8  NaN  NaN   c8  NaN   d8
# 9    a3  NaN   b9  NaN  NaN   c9  NaN   d9
# 10  a10  NaN  b10  NaN  NaN  c10  NaN  d10
# 11  a11  NaN  b11  NaN  NaN  c11  NaN  d11

# %%
row_concat2.to_csv('row_concat2.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-72-674d1b7d7998> in <module>
# ----> 1 row_concat2.to_csv('row_concat2.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'row_concat2.csv'

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: AE94-D5A8
#
#  C:\Users\hi\Himedia_jupyter\data03 디렉터리
#
# 2022-03-17  오후 04:40    <DIR>          .
# 2022-03-17  오후 04:40    <DIR>          ..
# 2022-03-17  오후 03:46    <DIR>          .ipynb_checkpoints
# 2022-03-17  오후 12:57            10,900 colab_test_1.ipynb
# 2022-03-17  오후 12:59           137,731 colab_test_2.ipynb
# 2022-03-17  오후 03:44            69,565 dataframe_test1.ipynb
# 2022-03-17  오후 04:38            61,090 dataframe_test2.ipynb
# 2022-03-17  오후 03:58               256 row_concat2.csv
#                5개 파일             279,542 바이트
#                3개 디렉터리  77,744,246,784 바이트 남음

# %%
df11
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
df22
# Out:
#     E   F   G   H
# 0  a4  b4  c4  d4
# 1  a5  b5  c5  d5
# 2  a6  b6  c6  d6
# 3  a7  b7  c7  d7

# %%
df33
# Out:
#      A    C    F    H
# 0   a1   b8   c8   d8
# 1   a3   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
row_concat3 = pd.read_csv('row_concat2.csv')
row_concat3
# Out:
#     Unnamed: 0    A    B    C    D    E    F    G    H
# 0            0   a0   b0   c0   d0  NaN  NaN  NaN  NaN
# 1            1   a1   b1   c1   d1  NaN  NaN  NaN  NaN
# 2            2   a2   b2   c2   d2  NaN  NaN  NaN  NaN
# 3            3   a3   b3   c3   d3  NaN  NaN  NaN  NaN
# 4            4  NaN  NaN  NaN  NaN   a4   b4   c4   d4
# 5            5  NaN  NaN  NaN  NaN   a5   b5   c5   d5
# 6            6  NaN  NaN  NaN  NaN   a6   b6   c6   d6
# 7            7  NaN  NaN  NaN  NaN   a7   b7   c7   d7
# 8            8   a1  NaN   b8  NaN  NaN   c8  NaN   d8
# 9            9   a3  NaN   b9  NaN  NaN   c9  NaN   d9
# 10          10  a10  NaN  b10  NaN  NaN  c10  NaN  d10
# 11          11  a11  NaN  b11  NaN  NaN  c11  NaN  d11

# %%
row_concat3.drop(columns='Unnamed: 0', inplace=True)
row_concat3
# Out:
#       A    B    C    D    E    F    G    H
# 0    a0   b0   c0   d0  NaN  NaN  NaN  NaN
# 1    a1   b1   c1   d1  NaN  NaN  NaN  NaN
# 2    a2   b2   c2   d2  NaN  NaN  NaN  NaN
# 3    a3   b3   c3   d3  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   a4   b4   c4   d4
# 5   NaN  NaN  NaN  NaN   a5   b5   c5   d5
# 6   NaN  NaN  NaN  NaN   a6   b6   c6   d6
# 7   NaN  NaN  NaN  NaN   a7   b7   c7   d7
# 8    a1  NaN   b8  NaN  NaN   c8  NaN   d8
# 9    a3  NaN   b9  NaN  NaN   c9  NaN   d9
# 10  a10  NaN  b10  NaN  NaN  c10  NaN  d10
# 11  a11  NaN  b11  NaN  NaN  c11  NaN  d11

# %%
row_append = df1.append(df2, ignore_index=True)
row_append
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5
# 6  a6  b6  c6  d6
# 7  a7  b7  c7  d7

# %%
# row_append.iloc[8] = ['a8', 'b8', 'c8', 'd8']
# row_append

# %%
new_dic = {'A': 'a8',
          'B': 'a8',
          'C': 'a8',
          'D': 'a8'}

# %%
row_append2 = row_append.append(new_dic, ignore_index=True)
row_append2
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5
# 6  a6  b6  c6  d6
# 7  a7  b7  c7  d7
# 8  a8  a8  a8  a8

# %%
row_concat3 = pd.concat([df11,df33], join='inner', ignore_index=True)
row_concat3
# 공통적으로 들어있는 항목들에 대해서만 합라하는 의미
# Out:
#      A    C
# 0   a0   c0
# 1   a1   c1
# 2   a2   c2
# 3   a3   c3
# 4   a1   b8
# 5   a3   b9
# 6  a10  b10
# 7  a11  b11

# %%
row_concat31 = pd.concat([df22,df33], join='inner', ignore_index=True)
row_concat31.head()
# Out:
#     F   H
# 0  b4  d4
# 1  b5  d5
# 2  b6  d6
# 3  b7  d7
# 4  c8  d8

# %%
type(row_concat31.head())
# Out:
# pandas.core.frame.DataFrame

# %%
df11
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
df33
# Out:
#      A    C    F    H
# 0   a1   b8   c8   d8
# 1   a3   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
pd.concat([df11,df33], join='outer', ignore_index=True)
# Out:
# C:\Users\hi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#      A    B    C    D    F    H
# 0   a0   b0   c0   d0  NaN  NaN
# 1   a1   b1   c1   d1  NaN  NaN
# 2   a2   b2   c2   d2  NaN  NaN
# 3   a3   b3   c3   d3  NaN  NaN
# 4   a1  NaN   b8  NaN   c8   d8
# 5   a3  NaN   b9  NaN   c9   d9
# 6  a10  NaN  b10  NaN  c10  d10
# 7  a11  NaN  b11  NaN  c11  d11

# %%
result = df11.merge(df33, on='A')

# %%
result
# Out:
#     A   B C_x   D C_y   F   H
# 0  a1  b1  c1  d1  b8  c8  d8
# 1  a3  b3  c3  d3  b9  c9  d9

# %%
df11
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
df33
# Out:
#      A    C    F    H
# 0   a1   b8   c8   d8
# 1   a3   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11
