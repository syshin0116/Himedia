# %%
# 0. scientist.csv
# 1. df로 읽어들이고
# 2. df의 전체 데이터셋 타입을 확인
# 3. df의 컬럼리스트를 확인
# 4. df의 값을 확인
# 5. df의 맨 마지막에 price항목을 추가(값은 임의대로 넣음. int)
# 6. df의 맨 마지막에 percent항목을 추가(값의 임의대로 넣음. float)
# 7. df의 맨 마지막에 sale항목을 추가(price * percent)
# 8. df의 Name컬럼 추출
# 9. df의 인덱스 확인
# 10. df의 Name컬럼의 값이 Rosaline인 행 추출
# 11. df의 Name컬럼 중 3~5사이의 행 추출
# 12. df의 Name, Died컬럼 모든 행 추출
# 13. df의 Born컬럼부터 끝컬럼까지 모든 행 추출
# 14. df의 Born, Age컬럼의 5~7행 추출
# 15. df.shape을 통해 몇행 몇열인지 확인해보세요.
# 16. df의 숫자 데이터의 상세정보 확인
# 17. Nurse라는 스트링 추출(index와 컬럼명을 사용)
# 18. Alan Turing이라는 스트링 추출(index와 컬럼명을 사용)
# 19. Biologist를 Scientist로 변경
# 20. df의 변경된 내용은 수시로 프린트해볼 것.

# %%
# info() : 항목별 갯수와 datatype

# %%
# head(5), tail(5) : 일부분

# %%
# describe(include='object')

# %%
# df[항목명].value_counts() : 항목의 개수, 타입

# %%
# df.T : 행, 열 전환

# %%
# df[항목명].astype('int32') : 항목의 타입 변환(float32, str, category)

# %%
# df.sort_index(), df.sort_index(ascending=False) : index로 정렬

# %%
# df.sort_values(by='age') : age컬럼으로 오름차순 정렬

# %%
# df.sort_values(by='age', ascending=False)

# %%
# df.sort_values(by=['fare', 'age'])

# %%
# df.sort_values(by=['fare', 'age'], ascending=[False, True])

# %%
# condition = df['who'] == 'man'
# df[condition], df.loc[condition]
# df[condition]['age']
# df[condition]['age'] = 2 (허용x)
# df.loc[condition, 'age'] = 2 (허용o)

# %%
# 조건1 정의
# condition1 = (df['fare'] > 30)

# 조건2 정의
# condition2 = (df['who'] == 'woman')

# %%
# df.loc[condition1 & condition2]

# %%
# df.loc[condition1 | condition2]

# %%
# df.loc[condition, 'age'] = 2 (허용o)

# %%
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# condition = df['who'] == 'man'
# # df[condition], df.loc[condition]
# df[condition]['age']

# %%
# 상위 10개를 출력
condition = df['age'] >= 30
df[condition]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 873         0       3    male  47.0      0      0   9.0000        S  Third
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 881         0       3    male  33.0      0      0   7.8958        S  Third
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# 6      man        True    E  Southampton    no   True
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 873    man        True  NaN  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 881    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 890    man        True  NaN   Queenstown    no   True
#
# [330 rows x 15 columns]

# %%
# fare를 많이 낸 순서로 내림차순 정렬
df.sort_values(by=['fare'], ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 258         1       1  female  35.0      0      0  512.3292        C   First
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 679         1       1    male  36.0      0      1  512.3292        C   First
# 88          1       1  female  23.0      3      2  263.0000        S   First
# 27          0       1    male  19.0      3      2  263.0000        S   First
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 633         0       1    male   NaN      0      0    0.0000        S   First
# 413         0       2    male   NaN      0      0    0.0000        S  Second
# 822         0       1    male  38.0      0      0    0.0000        S   First
# 732         0       2    male   NaN      0      0    0.0000        S  Second
# 674         0       2    male   NaN      0      0    0.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 258  woman       False  NaN    Cherbourg   yes   True
# 737    man        True    B    Cherbourg   yes   True
# 679    man        True    B    Cherbourg   yes  False
# 88   woman       False    C  Southampton   yes  False
# 27     man        True    C  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 633    man        True  NaN  Southampton    no   True
# 413    man        True  NaN  Southampton    no   True
# 822    man        True  NaN  Southampton    no   True
# 732    man        True  NaN  Southampton    no   True
# 674    man        True  NaN  Southampton    no   True
#
# [891 rows x 15 columns]

# %%
# 상위 10개를 출력
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
# 나이가 20살 이상 40살 미만인 승객
condition1 = df['age'] >= 20
condition2 = df['age'] < 40
df[condition1 & condition2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 884    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [387 rows x 15 columns]

# %%
# pclass가 1등급 혹은 2등급인 승객
condition = df['pclass'].isin([1,2])
df[condition]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 9    child       False  NaN    Cherbourg   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 880  woman       False  NaN  Southampton   yes  False
# 883    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [400 rows x 15 columns]

# %%
# 열(column)은 survived, pclass, age, fare 만 나오게 출력
df[['survived', 'pclass', 'age', 'fare']]
# Out:
#      survived  pclass   age     fare
# 0           0       3  22.0   7.2500
# 1           1       1  38.0  71.2833
# 2           1       3  26.0   7.9250
# 3           1       1  35.0  53.1000
# 4           0       3  35.0   8.0500
# ..        ...     ...   ...      ...
# 886         0       2  27.0  13.0000
# 887         1       1  19.0  30.0000
# 888         0       3   NaN  23.4500
# 889         1       1  26.0  30.0000
# 890         0       3  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
# 10개만 출력
df[['survived', 'pclass', 'age', 'fare']].sample(10)
# Out:
#      survived  pclass   age     fare
# 773         0       3   NaN   7.2250
# 674         0       2   NaN   0.0000
# 163         0       3  17.0   8.6625
# 874         1       2  28.0  24.0000
# 97          1       1  23.0  63.3583
# 166         1       1   NaN  55.0000
# 409         0       3   NaN  25.4667
# 61          1       1  38.0  80.0000
# 175         0       3  18.0   7.8542
# 869         1       3   4.0  11.1333

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df[df['pclass'].isin([1, 2])][['survived', 'pclass', 'age', 'fare']][:5]
# Out:
#     survived  pclass   age     fare
# 1          1       1  38.0  71.2833
# 3          1       1  35.0  53.1000
# 6          0       1  54.0  51.8625
# 9          1       2  14.0  30.0708
# 11         1       1  58.0  26.5500

# %%
type(df['survived'])
# Out:
# pandas.core.series.Series

# %%
type(df[['survived']])
# Out:
# pandas.core.frame.DataFrame

# %%
# df.isin(['kim', 'lee'])

# %%
condition = df['name'].isin(['kim', 'lee'])
# sample.loc[condition]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-f01a19390226> in <module>
# ----> 1 condition = df['name'].isin(['kim', 'lee'])
#       2 # sample.loc[condition]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'

# %%
df['VIP'] = True
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone   VIP
# 0      man        True  NaN  Southampton    no  False  True
# 1    woman       False    C    Cherbourg   yes  False  True
# 2    woman       False  NaN  Southampton   yes   True  True
# 3    woman       False    C  Southampton   yes  False  True
# 4      man        True  NaN  Southampton    no   True  True
# ..     ...         ...  ...          ...   ...    ...   ...
# 886    man        True  NaN  Southampton    no   True  True
# 887  woman       False    B  Southampton   yes   True  True
# 888  woman       False  NaN  Southampton    no  False  True
# 889    man        True    C    Cherbourg   yes   True  True
# 890    man        True  NaN   Queenstown    no   True  True
#
# [891 rows x 16 columns]

# %%
df.drop(1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone   VIP
# 0      man        True  NaN  Southampton    no  False  True
# 2    woman       False  NaN  Southampton   yes   True  True
# 3    woman       False    C  Southampton   yes  False  True
# 4      man        True  NaN  Southampton    no   True  True
# 5      man        True  NaN   Queenstown    no   True  True
# ..     ...         ...  ...          ...   ...    ...   ...
# 886    man        True  NaN  Southampton    no   True  True
# 887  woman       False    B  Southampton   yes   True  True
# 888  woman       False  NaN  Southampton    no  False  True
# 889    man        True    C    Cherbourg   yes   True  True
# 890    man        True  NaN   Queenstown    no   True  True
#
# [890 rows x 16 columns]

# %%
df.drop(df.index[0:10])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# 13          0       3    male  39.0      1      5  31.2750        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone   VIP
# 10   child       False    G  Southampton   yes  False  True
# 11   woman       False    C  Southampton   yes   True  True
# 12     man        True  NaN  Southampton    no   True  True
# 13     man        True  NaN  Southampton    no  False  True
# 14   child       False  NaN  Southampton    no   True  True
# ..     ...         ...  ...          ...   ...    ...   ...
# 886    man        True  NaN  Southampton    no   True  True
# 887  woman       False    B  Southampton   yes   True  True
# 888  woman       False  NaN  Southampton    no  False  True
# 889    man        True    C    Cherbourg   yes   True  True
# 890    man        True  NaN   Queenstown    no   True  True
#
# [881 rows x 16 columns]

# %%
df.drop(index=[1, 3, 5, 7, 9])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town  alone   VIP  round
# 0          True  Southampton  False  True   0.33
# 2         False  Southampton   True  True   0.30
# 4          True  Southampton   True  True   0.23
# 6          True  Southampton   True  True   0.96
# 8         False  Southampton  False  True   0.41
# ..          ...          ...    ...   ...    ...
# 886        True  Southampton   True  True   0.48
# 887       False  Southampton   True  True   1.58
# 888       False  Southampton  False  True    NaN
# 889        True    Cherbourg   True  True   1.15
# 890        True   Queenstown   True  True   0.24
#
# [886 rows x 14 columns]

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone   VIP
# 0      man        True  NaN  Southampton    no  False  True
# 1    woman       False    C    Cherbourg   yes  False  True
# 2    woman       False  NaN  Southampton   yes   True  True
# 3    woman       False    C  Southampton   yes  False  True
# 4      man        True  NaN  Southampton    no   True  True
# ..     ...         ...  ...          ...   ...    ...   ...
# 886    man        True  NaN  Southampton    no   True  True
# 887  woman       False    B  Southampton   yes   True  True
# 888  woman       False  NaN  Southampton    no  False  True
# 889    man        True    C    Cherbourg   yes   True  True
# 890    man        True  NaN   Queenstown    no   True  True
#
# [891 rows x 16 columns]

# %%
df.drop(['class', 'sex'], 1)
# Out:
#      survived  pclass   age  sibsp  parch     fare embarked    who  \
# 0           0       3  22.0      1      0   7.2500        S    man
# 1           1       1  38.0      1      0  71.2833        C  woman
# 2           1       3  26.0      0      0   7.9250        S  woman
# 3           1       1  35.0      1      0  53.1000        S  woman
# 4           0       3  35.0      0      0   8.0500        S    man
# ..        ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       2  27.0      0      0  13.0000        S    man
# 887         1       1  19.0      0      0  30.0000        S  woman
# 888         0       3   NaN      1      2  23.4500        S  woman
# 889         1       1  26.0      0      0  30.0000        C    man
# 890         0       3  32.0      0      0   7.7500        Q    man
#
#      adult_male deck  embark_town alive  alone   VIP
# 0          True  NaN  Southampton    no  False  True
# 1         False    C    Cherbourg   yes  False  True
# 2         False  NaN  Southampton   yes   True  True
# 3         False    C  Southampton   yes  False  True
# 4          True  NaN  Southampton    no   True  True
# ..          ...  ...          ...   ...    ...   ...
# 886        True  NaN  Southampton    no   True  True
# 887       False    B  Southampton   yes   True  True
# 888       False  NaN  Southampton    no  False  True
# 889        True    C    Cherbourg   yes   True  True
# 890        True  NaN   Queenstown    no   True  True
#
# [891 rows x 14 columns]

# %%
df.drop(['who', 'deck', 'alive'], axis=1)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone   VIP
# 0      man        True  NaN  Southampton    no  False  True
# 1    woman       False    C    Cherbourg   yes  False  True
# 2    woman       False  NaN  Southampton   yes   True  True
# 3    woman       False    C  Southampton   yes  False  True
# 4      man        True  NaN  Southampton    no   True  True
# ..     ...         ...  ...          ...   ...    ...   ...
# 886    man        True  NaN  Southampton    no   True  True
# 887  woman       False    B  Southampton   yes   True  True
# 888  woman       False  NaN  Southampton    no  False  True
# 889    man        True    C    Cherbourg   yes   True  True
# 890    man        True  NaN   Queenstown    no   True  True
#
# [891 rows x 16 columns]

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone   VIP
# 0      man        True  NaN  Southampton    no  False  True
# 1    woman       False    C    Cherbourg   yes  False  True
# 2    woman       False  NaN  Southampton   yes   True  True
# 3    woman       False    C  Southampton   yes  False  True
# 4      man        True  NaN  Southampton    no   True  True
# ..     ...         ...  ...          ...   ...    ...   ...
# 886    man        True  NaN  Southampton    no   True  True
# 887  woman       False    B  Southampton   yes   True  True
# 888  woman       False  NaN  Southampton    no  False  True
# 889    man        True    C    Cherbourg   yes   True  True
# 890    man        True  NaN   Queenstown    no   True  True
#
# [891 rows x 16 columns]

# %%
df.drop(['who', 'deck', 'alive'], axis=1, inplace=True)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town  alone   VIP
# 0          True  Southampton  False  True
# 1         False    Cherbourg  False  True
# 2         False  Southampton   True  True
# 3         False  Southampton  False  True
# 4          True  Southampton   True  True
# ..          ...          ...    ...   ...
# 886        True  Southampton   True  True
# 887       False  Southampton   True  True
# 888       False  Southampton  False  True
# 889        True    Cherbourg   True  True
# 890        True   Queenstown   True  True
#
# [891 rows x 13 columns]

# %%
df1 = df.copy()
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town  alone   VIP
# 0          True  Southampton  False  True
# 1         False    Cherbourg  False  True
# 2         False  Southampton   True  True
# 3         False  Southampton  False  True
# 4          True  Southampton   True  True
# ..          ...          ...    ...   ...
# 886        True  Southampton   True  True
# 887       False  Southampton   True  True
# 888       False  Southampton  False  True
# 889        True    Cherbourg   True  True
# 890        True   Queenstown   True  True
#
# [891 rows x 13 columns]

# %%
df['round'] = round(df['fare'] / df['age'], 2)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town  alone   VIP  round
# 0          True  Southampton  False  True   0.33
# 1         False    Cherbourg  False  True   1.88
# 2         False  Southampton   True  True   0.30
# 3         False  Southampton  False  True   1.52
# 4          True  Southampton   True  True   0.23
# ..          ...          ...    ...   ...    ...
# 886        True  Southampton   True  True   0.48
# 887       False  Southampton   True  True   1.58
# 888       False  Southampton  False  True    NaN
# 889        True    Cherbourg   True  True   1.15
# 890        True   Queenstown   True  True   0.24
#
# [891 rows x 14 columns]

# %%
df.loc[:,'sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
df['sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
type(df['sex'])
# Out:
# pandas.core.series.Series

# %%
df['pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
import pandas as pd
import numpy as np

# %%
df[['pclass', 'sex']].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-fc05a1363ddd> in <module>
# ----> 1 df[['pclass', 'sex']].value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
type(df.iloc[:, [0,2]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.category.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-adaf3ed65cbf> in <module>
# ----> 1 df.category.value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'category'

# %%
result2 = df[df['pclass'].isin([1, 2])]

# %%
df[['pclass', 'age']].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-7403ec119667> in <module>
# ----> 1 df[['pclass', 'age']].value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
result2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#      adult_male  embark_town  alone   VIP  round
# 1         False    Cherbourg  False  True   1.88
# 3         False  Southampton  False  True   1.52
# 6          True  Southampton   True  True   0.96
# 9         False    Cherbourg  False  True   2.15
# 11        False  Southampton   True  True   0.46
# ..          ...          ...    ...   ...    ...
# 880       False  Southampton  False  True   1.04
# 883        True  Southampton   True  True   0.38
# 886        True  Southampton   True  True   0.48
# 887       False  Southampton   True  True   1.58
# 889        True    Cherbourg   True  True   1.15
#
# [400 rows x 14 columns]
