# %%
import pandas as pd
import numpy as np

# %%
cctv_seoul = pd.read_csv('../csv-data/cctv_seoul.csv')
cctv_seoul.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
cctv_seoul.columns
# Out:
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
cctv_seoul.columns[0]
# Out:
# '기관명'

# %%
cctv_seoul.rename(columns={cctv_seoul.columns[0]:'구별'}, inplace=True)

# %%
cctv_seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
pop_seoul = pd.read_excel('../csv-data/pop_seoul.xls', encoding='utf8',
                          header = 2,
                          usecols= 'B,D,G,J,N'
                         )

pop_seoul
# Out:
#      자치구           계        계.1       계.2   65세이상고령자
# 0     합계  10197604.0  9926968.0  270636.0  1321458.0
# 1    종로구    162820.0   153589.0    9231.0    25425.0
# 2     중구    133240.0   124312.0    8928.0    20764.0
# 3    용산구    244203.0   229456.0   14747.0    36231.0
# 4    성동구    311244.0   303380.0    7864.0    39997.0
# 5    광진구    372164.0   357211.0   14953.0    42214.0
# 6   동대문구    369496.0   354079.0   15417.0    54173.0
# 7    중랑구    414503.0   409882.0    4621.0    56774.0
# 8    성북구    461260.0   449773.0   11487.0    64692.0
# 9    강북구    330192.0   326686.0    3506.0    54813.0
# 10   도봉구    348646.0   346629.0    2017.0    51312.0
# 11   노원구    569384.0   565565.0    3819.0    71941.0
# 12   은평구    494388.0   489943.0    4445.0    72334.0
# 13  서대문구    327163.0   314982.0   12181.0    48161.0
# 14   마포구    389649.0   378566.0   11083.0    48765.0
# 15   양천구    479978.0   475949.0    4029.0    52975.0
# 16   강서구    603772.0   597248.0    6524.0    72548.0
# ...

# %%
cctv_seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
#cctv가 제일 많이 설치되어있는 구, 제일 적게 설치되어 있는 구를 순서대로 정렬
cctv_seoul.sort_values(by='소계').head()
# Out:
#      구별   소계  2013년도 이전  2014년  2015년  2016년
# 9   도봉구  485        238    159     42    386
# 12  마포구  574        314    118    169    379
# 17  송파구  618        529     21     68    463
# 24  중랑구  660        509    121    177    109
# 23   중구  671        413    190     72    348

# %%
cctv_seoul.sort_values(by='소계').tail()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년
# 20  용산구  1624       1368    218    112    398
# 21  은평구  1873       1138    224    278    468
# 14  서초구  1930       1406    157    336    398
# 18  양천구  2034       1843    142     30    467
# 0   강남구  2780       1292    430    584    932

# %%
##내림차순(descending):
cctv_seoul.sort_values(by='소계', ascending=False).head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년
# 0   강남구  2780       1292    430    584    932
# 18  양천구  2034       1843    142     30    467
# 14  서초구  1930       1406    157    336    398
# 21  은평구  1873       1138    224    278    468
# 20  용산구  1624       1368    218    112    398

# %%
pop_seoul.columns
# Out:
# Index(['자치구', '계', '계.1', '계.2', '65세이상고령자'], dtype='object')

# %%
# 인구수의 컬럼을 '구별', '인구수', '한국인', '외국인', 고령자
pop_seoul.columns = ['구별', '인구수', '한국인', '외국인', '고령자']
pop_seoul
# Out:
#       구별         인구수        한국인       외국인        고령자
# 0     합계  10197604.0  9926968.0  270636.0  1321458.0
# 1    종로구    162820.0   153589.0    9231.0    25425.0
# 2     중구    133240.0   124312.0    8928.0    20764.0
# 3    용산구    244203.0   229456.0   14747.0    36231.0
# 4    성동구    311244.0   303380.0    7864.0    39997.0
# 5    광진구    372164.0   357211.0   14953.0    42214.0
# 6   동대문구    369496.0   354079.0   15417.0    54173.0
# 7    중랑구    414503.0   409882.0    4621.0    56774.0
# 8    성북구    461260.0   449773.0   11487.0    64692.0
# 9    강북구    330192.0   326686.0    3506.0    54813.0
# 10   도봉구    348646.0   346629.0    2017.0    51312.0
# 11   노원구    569384.0   565565.0    3819.0    71941.0
# 12   은평구    494388.0   489943.0    4445.0    72334.0
# 13  서대문구    327163.0   314982.0   12181.0    48161.0
# 14   마포구    389649.0   378566.0   11083.0    48765.0
# 15   양천구    479978.0   475949.0    4029.0    52975.0
# 16   강서구    603772.0   597248.0    6524.0    72548.0
# ...

# %%
#합계라고 되어잇는 행을 삭제
pop_seoul.drop([0], inplace=True)
pop_seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자
# 1  종로구  162820.0  153589.0   9231.0  25425.0
# 2   중구  133240.0  124312.0   8928.0  20764.0
# 3  용산구  244203.0  229456.0  14747.0  36231.0
# 4  성동구  311244.0  303380.0   7864.0  39997.0
# 5  광진구  372164.0  357211.0  14953.0  42214.0

# %%
pop_seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 1 to 26
# Data columns (total 5 columns):
# 구별     25 non-null object
# 인구수    25 non-null float64
# 한국인    25 non-null float64
# 외국인    25 non-null float64
# 고령자    25 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 1.2+ KB

# %%
pop_seoul['구별']
# Out:
# 1      종로구
# 2       중구
# 3      용산구
# 4      성동구
# 5      광진구
# 6     동대문구
# 7      중랑구
# 8      성북구
# 9      강북구
# 10     도봉구
# 11     노원구
# 12     은평구
# 13    서대문구
# 14     마포구
# 15     양천구
# 16     강서구
# 17     구로구
# 18     금천구
# 19    영등포구
# 20     동작구
# 21     관악구
# 22     서초구
# 23     강남구
# 24     송파구
# 25     강동구
# 26     NaN
# Name: 구별, dtype: object

# %%
len(pop_seoul['구별'].unique())
# Out:
# 26

# %%
pop_seoul
# Out:
#       구별       인구수       한국인      외국인      고령자
# 1    종로구  162820.0  153589.0   9231.0  25425.0
# 2     중구  133240.0  124312.0   8928.0  20764.0
# 3    용산구  244203.0  229456.0  14747.0  36231.0
# 4    성동구  311244.0  303380.0   7864.0  39997.0
# 5    광진구  372164.0  357211.0  14953.0  42214.0
# 6   동대문구  369496.0  354079.0  15417.0  54173.0
# 7    중랑구  414503.0  409882.0   4621.0  56774.0
# 8    성북구  461260.0  449773.0  11487.0  64692.0
# 9    강북구  330192.0  326686.0   3506.0  54813.0
# 10   도봉구  348646.0  346629.0   2017.0  51312.0
# 11   노원구  569384.0  565565.0   3819.0  71941.0
# 12   은평구  494388.0  489943.0   4445.0  72334.0
# 13  서대문구  327163.0  314982.0  12181.0  48161.0
# 14   마포구  389649.0  378566.0  11083.0  48765.0
# 15   양천구  479978.0  475949.0   4029.0  52975.0
# 16   강서구  603772.0  597248.0   6524.0  72548.0
# 17   구로구  447874.0  416487.0  31387.0  56833.0
# 18   금천구  255082.0  236353.0  18729.0  32970.0
# 19  영등포구  402985.0  368072.0  34913.0  52413.0
# ...

# %%
pop_seoul.drop([26], inplace=True)
pop_seoul
# Out:
#       구별       인구수       한국인      외국인      고령자
# 1    종로구  162820.0  153589.0   9231.0  25425.0
# 2     중구  133240.0  124312.0   8928.0  20764.0
# 3    용산구  244203.0  229456.0  14747.0  36231.0
# 4    성동구  311244.0  303380.0   7864.0  39997.0
# 5    광진구  372164.0  357211.0  14953.0  42214.0
# 6   동대문구  369496.0  354079.0  15417.0  54173.0
# 7    중랑구  414503.0  409882.0   4621.0  56774.0
# 8    성북구  461260.0  449773.0  11487.0  64692.0
# 9    강북구  330192.0  326686.0   3506.0  54813.0
# 10   도봉구  348646.0  346629.0   2017.0  51312.0
# 11   노원구  569384.0  565565.0   3819.0  71941.0
# 12   은평구  494388.0  489943.0   4445.0  72334.0
# 13  서대문구  327163.0  314982.0  12181.0  48161.0
# 14   마포구  389649.0  378566.0  11083.0  48765.0
# 15   양천구  479978.0  475949.0   4029.0  52975.0
# 16   강서구  603772.0  597248.0   6524.0  72548.0
# 17   구로구  447874.0  416487.0  31387.0  56833.0
# 18   금천구  255082.0  236353.0  18729.0  32970.0
# 19  영등포구  402985.0  368072.0  34913.0  52413.0
# ...

# %%
pop_seoul.isnull().sum()
# Out:
# 구별     0
# 인구수    0
# 한국인    0
# 외국인    0
# 고령자    0
# dtype: int64

# %%
pop_seoul['구별'].isna().sum()
# Out:
# 0

# %%
#외국인 비율, 고령자비율 파생변수를 2개 만드어주세요!
pop_seoul['외국인비율']=pop_seoul['외국인']/pop_seoul['인구수']*100
pop_seoul['고령자비율']=pop_seoul['고령자']/pop_seoul['인구수']*100
pop_seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 1  종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2   중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3  용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 4  성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689
# 5  광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849

# %%
pop_seoul.sort_values(by='인구수', ascending=False).head() #체인식 코드
# Out:
#      구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 24  송파구  667483.0  660584.0   6899.0  72506.0  1.033584  10.862599
# 16  강서구  603772.0  597248.0   6524.0  72548.0  1.080540  12.015794
# 23  강남구  570500.0  565550.0   4950.0  63167.0  0.867660  11.072217
# 11  노원구  569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 21  관악구  525515.0  507203.0  18312.0  68082.0  3.484582  12.955291

# %%
pop_seoul.sort_values(by='인구수', ascending=False).tail()
# Out:
#      구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 4   성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689
# 18  금천구  255082.0  236353.0  18729.0  32970.0  7.342345  12.925255
# 3   용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 1   종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2    중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909

# %%
#고령자 비율이 높은 구는 어디인가?
pop_seoul.sort_values(by='고령자비율', ascending=False).head()
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 9    강북구  330192.0  326686.0   3506.0  54813.0  1.061806  16.600342
# 1    종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2     중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3    용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 13  서대문구  327163.0  314982.0  12181.0  48161.0  3.723221  14.720797

# %%
#외국인이 비율이 높은 구는 어디인가?
pop_seoul.sort_values(by='외국인비율', ascending=False).head()
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 19  영등포구  402985.0  368072.0  34913.0  52413.0  8.663598  13.006191
# 18   금천구  255082.0  236353.0  18729.0  32970.0  7.342345  12.925255
# 17   구로구  447874.0  416487.0  31387.0  56833.0  7.007998  12.689506
# 2     중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3    용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427

# %%
#고량자 비율이 낮은 구는 어디인가?
pop_seoul.sort_values(by='고령자비율').head()
# Out:
#      구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 24  송파구  667483.0  660584.0   6899.0  72506.0  1.033584  10.862599
# 15  양천구  479978.0  475949.0   4029.0  52975.0  0.839413  11.036964
# 23  강남구  570500.0  565550.0   4950.0  63167.0  0.867660  11.072217
# 5   광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849
# 22  서초구  450310.0  445994.0   4316.0  51733.0  0.958451  11.488308

# %%
#외국인 비율이 낮은 구는 어디인가?
pop_seoul.sort_values(by='외국인비율').head()
# Out:
#      구별       인구수       한국인     외국인      고령자     외국인비율      고령자비율
# 10  도봉구  348646.0  346629.0  2017.0  51312.0  0.578524  14.717507
# 11  노원구  569384.0  565565.0  3819.0  71941.0  0.670725  12.634883
# 15  양천구  479978.0  475949.0  4029.0  52975.0  0.839413  11.036964
# 23  강남구  570500.0  565550.0  4950.0  63167.0  0.867660  11.072217
# 12  은평구  494388.0  489943.0  4445.0  72334.0  0.899091  14.631019

# %%
cctv_seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
#cctv 최근 증가율이 높은곳/낮은 곳
cctv_seoul['최근증가율'] = (cctv_seoul['2014년'] + cctv_seoul['2015년'] + cctv_seoul['2016년'])/ (cctv_seoul['2013년도 이전'])*100
cctv_seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 0  강남구  2780       1292    430    584    932  150.619195
# 1  강동구   773        379     99    155    377  166.490765
# 2  강북구   748        369    120    138    204  125.203252
# 3  강서구   884        388    258    184     81  134.793814
# 4  관악구  1496        846    260    390    613  149.290780

# %%
cctv_seoul.sort_values(by='최근증가율', ascending=False).head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 22  종로구  1002        464    314    211    630  248.922414
# 9   도봉구   485        238    159     42    386  246.638655
# 12  마포구   574        314    118    169    379  212.101911
# 8   노원구  1265        542     57    451    516  188.929889
# 1   강동구   773        379     99    155    377  166.490765

# %%
data_result = pd.merge(cctv_seoul, pop_seoul)
data_result
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율       인구수  \
# 0    강남구  2780       1292    430    584    932  150.619195  570500.0
# 1    강동구   773        379     99    155    377  166.490765  453233.0
# 2    강북구   748        369    120    138    204  125.203252  330192.0
# 3    강서구   884        388    258    184     81  134.793814  603772.0
# 4    관악구  1496        846    260    390    613  149.290780  525515.0
# 5    광진구   707        573     78     53    174   53.228621  372164.0
# 6    구로구  1561       1142    173    246    323   64.973730  447874.0
# 7    금천구  1015        674     51    269    354  100.000000  255082.0
# 8    노원구  1265        542     57    451    516  188.929889  569384.0
# 9    도봉구   485        238    159     42    386  246.638655  348646.0
# 10  동대문구  1294       1070     23    198    579   74.766355  369496.0
# 11   동작구  1091        544    341    103    314  139.338235  412520.0
# 12   마포구   574        314    118    169    379  212.101911  389649.0
# ...

# %%
data_result.drop(columns=['2013년도 이전', '2014년', '2015년', '2016년'], inplace=True)
data_result.head()
# Out:
#     구별    소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 0  강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 1  강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 2  강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 3  강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 4  관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#        고령자비율
# 0  11.072217
# 1  12.051638
# 2  16.600342
# 3  12.015794
# 4  12.955291

# %%
# del data_result['2014년'] => 한 피쳐(열) 삭제시 편함
# df.drop(columns=[컬럼명, 컬럼명, ...]) => 여러개의 피쳐 삭제시 편함

# %%
data_result['구별'].unique()
# Out:
# array(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
#        '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'], dtype=object)

# %%
type(data_result['구별'].unique())
# Out:
# numpy.ndarray

# %%
#1차원 ndarray객체는 1차원 list이므로, list처럼 다루면 됨.
len(data_result['구별'].unique())
# Out:
# 25

# %%
# reset_index(): 현재 index로 잡혀져있는 정수값이 df의 병합과 처리로 인해 순서대로 들어있지 않은 경우, 다시 순서대로 인덱스 값이 정렬되도록 함.
#                a_df_index=[1,2,3], b_df_index = [1,2,3]
#                a_df_index+b_df_index인 결과는 [1,2,3,1,2,3] 중복된 값!
#                reset_index()후 [0,1,2,3,4,5]
# set_index(): 특정한 unique한 값을 가지는 컬럼을 index로 설정하고자 하는 경우

# %%
data_result.set_index('구별', inplace=True)
data_result.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율
# 구별
# 강남구  11.072217
# 강동구  12.051638
# 강북구  16.600342
# 강서구  12.015794
# 관악구  12.955291

# %%
data_result['소계'].duplicated()
# Out:
# 구별
# 강남구     False
# 강동구     False
# 강북구     False
# 강서구     False
# 관악구     False
# 광진구     False
# 구로구     False
# 금천구     False
# 노원구     False
# 도봉구     False
# 동대문구    False
# 동작구     False
# 마포구     False
# 서대문구    False
# 서초구     False
# 성동구     False
# 성북구     False
# 송파구     False
# 양천구     False
# 영등포구    False
# 용산구     False
# 은평구     False
# 종로구     False
# 중구      False
# 중랑구     False
# Name: 소계, dtype: bool

# %%
# 고령자비율, 소계의 상관관계
old = np.corrcoef(data_result['고령자비율'], data_result['소계'])
old
# => 고령자비율이 높은 지역이 cctv가 많이 설치되었다라고 일번적으로 말할 수 없음
# => 고령자비율과 cctv설치수는 약간 음의 상관이 있긴 함
# Out:
# array([[ 1.        , -0.28078554],
#        [-0.28078554,  1.        ]])

# %%
# 외국인비율, 소계의 상관관계
out = np.corrcoef(data_result['외국인비율'], data_result['소계'])
out
# => 10프로에 가까운 수치이므로, 외국인비율과 cctv설치수는 거의 상관이 없음.
# 외국인이 높은 구가 cctv가 많이/적게 설치되어있다라고 할 수 없음
# Out:
# array([[ 1.        , -0.13607433],
#        [-0.13607433,  1.        ]])

# %%
#인수구, 소계의 상관관계
tot_pop = np.corrcoef(data_result['인구수'], data_result['소계'])
tot_pop
# => 인구수와 cctv설치수는 약간 양의 상관이 있다
# 인구수가 높은 지역이 소계가 높다라고 할 수 잇는 여지는 3-% 정도이다.
# 상관도가 높지는 않다

#cctv설치와 제일 상관있는 항목은 무엇인가요?
# 고령자 비율, 외국인 비율, 인구수 3항목중에서는 '인구수'가 제일 cctv설치수와 상관이 있는 것으로 확인됨.
# Out:
# array([[1.        , 0.30634228],
#        [0.30634228, 1.        ]])

# %%
# 세가지의 상관도를 그래프로 비교해보고 싶음.

# %%
#최근증가율과 소계의 상관관계
np.corrcoef(data_result['소계'], data_result['최근증가율'])
# => 최근증가율과 cctv설치수는 약간 음의 상관이 있다
# Out:
# array([[ 1.      , -0.343016],
#        [-0.343016,  1.      ]])

# %%
pop_seoul
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 1    종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2     중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3    용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 4    성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689
# 5    광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849
# 6   동대문구  369496.0  354079.0  15417.0  54173.0  4.172440  14.661322
# 7    중랑구  414503.0  409882.0   4621.0  56774.0  1.114829  13.696885
# 8    성북구  461260.0  449773.0  11487.0  64692.0  2.490353  14.025062
# 9    강북구  330192.0  326686.0   3506.0  54813.0  1.061806  16.600342
# 10   도봉구  348646.0  346629.0   2017.0  51312.0  0.578524  14.717507
# 11   노원구  569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 12   은평구  494388.0  489943.0   4445.0  72334.0  0.899091  14.631019
# 13  서대문구  327163.0  314982.0  12181.0  48161.0  3.723221  14.720797
# ...

# %%
pop_seoul['인구수'].tolist() ##list(1d) <----Series(1d)
# Out:
# [162820.0,
#  133240.0,
#  244203.0,
#  311244.0,
#  372164.0,
#  369496.0,
#  414503.0,
#  461260.0,
#  330192.0,
#  348646.0,
#  569384.0,
#  494388.0,
#  327163.0,
#  389649.0,
#  479978.0,
#  603772.0,
#  447874.0,
#  255082.0,
#  402985.0,
#  412520.0,
#  525515.0,
#  450310.0,
#  570500.0,
#  667483.0,
#  453233.0]

# %%
#ndarray가 list(), tolist()적용 여부 확인해봅시다!
tot_list = tot_pop.tolist() #2d list <---2nd array
tot_list
# Out:
# [[0.9999999999999999, 0.30634227936792635], [0.3063422793679263, 1.0]]

# %%
tot_list[0]
# Out:
# [0.9999999999999999, 0.30634227936792635]

# %%
tot_list[0][1]
# Out:
# 0.30634227936792635

# %%
tot_list[1]
# Out:
# [0.3063422793679263, 1.0]

# %%
fst_list=[1,2,3] # 1ndarray
fst_list
# Out:
# [1, 2, 3]

# %%
fst_list[0]
# Out:
# 1

# %%
#인덱스:0부터 시작 
snd_list=[
    #열
    [1,2,3],#행
    [4,5,6]
]
snd_list
#df.values < 2nd array
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
snd_list[1][1]
# Out:
# 5

# %%
tot_list
# Out:
# [[0.9999999999999999, 0.30634227936792635], [0.3063422793679263, 1.0]]

# %%
tot_corr = tot_list[0][1] # 전체 인구수 상관계수
tot_corr
# Out:
# 0.30634227936792635

# %%
list(tot_pop) #2d list <-----2ndarray
# Out:
# [array([1.        , 0.30634228]), array([0.30634228, 1.        ])]

# %%
old_list = old.tolist()
out_list = out.tolist()
old_list
# Out:
# [[1.0, -0.28078553790050065], [-0.2807855379005007, 1.0]]

# %%
out_list
# Out:
# [[0.9999999999999998, -0.13607432878194445], [-0.13607432878194445, 1.0]]

# %%
old_corr = old_list[0][1]
out_corr = out_list[0][1]

# %%
import matplotlib.pyplot as plt
plt.plot(['tot', 'old', 'out'], [tot_corr, old_corr, out_corr], 'ro')

# %%
#세가지의 상관도를 그래프로 비교해보고 싶음

# %%
pop_seoul[pop_seoul['구별']=='강남구']
# Out:
#      구별       인구수       한국인     외국인      고령자    외국인비율      고령자비율
# 23  강남구  570500.0  565550.0  4950.0  63167.0  0.86766  11.072217

# %%
#한국인, 외국인, 고령자 수를 비교할 수 있게 그래프를 그려보세요
gangnam = pop_seoul[pop_seoul['구별']=='강남구'][['한국인', '외국인', '고령자']]
gangnam
# Out:
#          한국인     외국인      고령자
# 23  565550.0  4950.0  63167.0

# %%
gn_kor = gangnam['한국인'].tolist()
gn_for = gangnam['외국인'].tolist()
gn_old = gangnam['고령자'].tolist()

# %%
plt.plot(['kor', 'foreign', 'old'], [gn_kor, gn_for, gn_old], 'ro')

# %%
#최근증가율과 소계의 상관관계
data_result.corr()
# Out:
#              소계     최근증가율       인구수       한국인       외국인       고령자     외국인비율  \
# 소계     1.000000 -0.343016  0.306342  0.304287 -0.023786  0.255196 -0.136074
# 최근증가율 -0.343016  1.000000 -0.093068 -0.082511 -0.150463 -0.070969 -0.044042
# 인구수    0.306342 -0.093068  1.000000  0.998061 -0.153371  0.932667 -0.591939
# 한국인    0.304287 -0.082511  0.998061  1.000000 -0.214576  0.931636 -0.637911
# 외국인   -0.023786 -0.150463 -0.153371 -0.214576  1.000000 -0.155381  0.838904
# 고령자    0.255196 -0.070969  0.932667  0.931636 -0.155381  1.000000 -0.606088
# 외국인비율 -0.136074 -0.044042 -0.591939 -0.637911  0.838904 -0.606088  1.000000
# 고령자비율 -0.280786  0.185089 -0.669462 -0.660812 -0.014055 -0.380468  0.267348
#
#           고령자비율
# 소계    -0.280786
# 최근증가율  0.185089
# 인구수   -0.669462
# 한국인   -0.660812
# 외국인   -0.014055
# 고령자   -0.380468
# 외국인비율  0.267348
# 고령자비율  1.000000

# %%
from matplotlib import rc
import matplotlib.font_manager as fm

fm._rebuild()
fm.get_fontconfig_fonts()

# 디렉토리 및 파일 이름에 맞추어 변경
font_location = '../NanumGothic.ttf'

font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)

# %%
#heatmap
#pairplot
import seaborn as sns
plt.matshow(data_result.corr())
plt.colorbar(shrink=0.8, aspect=10)
plt.show()
# Out:
# C:\Users\hi\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hi\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.pairplot(data_result.corr())
# Out:
# C:\Users\hi\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hi\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#구별 소계를 그래프로 그려봅시다!!
data_result['소계'].plot(kind='barh', grid=True, figsize=(10, 10))

# %%
plt.figure()
data_result['소계'].sort_values().plot(kind='barh', grid=True, figsize=(10, 10))
plt.show()

# %%
#인구당 cctv비율을 구해서, 정렬후, 그래프를 그려보세요!
data_result['인구당 cctv']=data_result['소계']/data_result['인구수']*100
data_result['인구당 cctv'].sort_values().plot(kind='barh', grid=True, figsize=(10, 10))
plt.show()

# %%
np.random.seed(0)
arr = np.random.standard_normal((8, 25))
plt.scatter(data_result['인구수'], data_result['소계'], c=arr[1], s=50)
plt.text(400000, 1500, '하')
plt.xlabel('인구수')
plt.ylabel('cctv개수')
plt.spring()
plt.show()

# %%
## x, y축으로 사용할 데이터를 주고, 1차방정식으로 표현했을 떄
## 기울기와 y절편을 구해주세요. polyfit()
pf1 = np.polyfit(data_result['인구수'], data_result['소계'], 1)
pf1
# Out:
# array([1.30916415e-03, 6.45066497e+02])

# %%
##위에서 구한 기울기와 절편으로 함수를 만들어주세요!
f1 = np.poly1d(pf1)
f1
# Out:
# poly1d([1.30916415e-03, 6.45066497e+02])

# %%
fx = np.linspace(100000,700000, 100)
fx
# Out:
# array([100000.        , 106060.60606061, 112121.21212121, 118181.81818182,
#        124242.42424242, 130303.03030303, 136363.63636364, 142424.24242424,
#        148484.84848485, 154545.45454545, 160606.06060606, 166666.66666667,
#        172727.27272727, 178787.87878788, 184848.48484848, 190909.09090909,
#        196969.6969697 , 203030.3030303 , 209090.90909091, 215151.51515152,
#        221212.12121212, 227272.72727273, 233333.33333333, 239393.93939394,
#        245454.54545455, 251515.15151515, 257575.75757576, 263636.36363636,
#        269696.96969697, 275757.57575758, 281818.18181818, 287878.78787879,
#        293939.39393939, 300000.        , 306060.60606061, 312121.21212121,
#        318181.81818182, 324242.42424242, 330303.03030303, 336363.63636364,
#        342424.24242424, 348484.84848485, 354545.45454545, 360606.06060606,
#        366666.66666667, 372727.27272727, 378787.87878788, 384848.48484848,
# ...

# %%
np.random.seed(0)
arr = np.random.standard_normal((8, 25))
plt.figure(figsize=(15,10))
plt.scatter(data_result['인구수'], data_result['소계'], c=arr[1], s=50)

plt.plot(fx, f1(fx), ls ='dashed' ,c='r')
for i in range(len(data_result['인구수'])):
    plt.annotate(data_result.index[i], (data_result['인구수'][i], data_result['소계'][i] + 0.2))
plt.text(400000, 1500, '하')
plt.xlabel('인구수')
plt.ylabel('cctv개수')
plt.spring()
plt.show()

# %%
# 판단선(회귀선): 예측과 분류의 기준이 되는 선!
# 판단선은 방정식, 1차 방정식이라고 한다면 기울기와 절편이 필요

# %%
# 위의 그래프는 무엇을 나타내는가?
# =>현재 서울의 인구수에 따른 cctv구별 설치 수를 나타냄
# cctv를 어느 구에 설치해야하는가?
# =>판단선: 인구수에 적정한 cctv수를 판단하는 선
#     판단선의 위에 위치한 구는 이미 인구수에 비해 cctv가 많이 성치된 구
#     판단선 아래에 위치한 구는 인구수에 비해 cctv가 설치가 부족한 구
#     판단선 아래에 위치한 구에 cctv를 설치하자!
#     오차가 큰 순으로! 먼저 선별을 하면 될 것 같음
# 판단기준: 인구수와 cctv와 관련있다라는 기준!

# %%
# 오차를 구해보자!
# 판단선의 값들이 필요
# f1(data_result['인구수'])
# 현재값들이 필요
# data_result['소계']
data_result['오차'] = data_result['소계']-f1(data_result['인구수'])
data_result.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율  인구당 cctv           오차
# 구별
# 강남구  11.072217  0.487292  1388.055355
# 강동구  12.051638  0.170552  -465.422892
# 강북구  16.600342  0.226535  -329.342026
# 강서구  12.015794  0.146413  -551.503155
# 관악구  12.955291  0.284673   162.948104

# %%
df_sort = data_result.sort_values(by='오차', ascending=False)
df_sort.tail()
# Out:
#       소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 중랑구  660   79.960707  414503.0  409882.0   4621.0  56774.0  1.114829
# 강서구  884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 마포구  574  212.101911  389649.0  378566.0  11083.0  48765.0  2.844355
# 도봉구  485  246.638655  348646.0  346629.0   2017.0  51312.0  0.578524
# 송파구  618  104.347826  667483.0  660584.0   6899.0  72506.0  1.033584
#
#          고령자비율  인구당 cctv          오차
# 구별
# 중랑구  13.696885  0.159227 -527.718965
# 강서구  12.015794  0.146413 -551.503155
# 마포구  12.515110  0.147312 -581.180999
# 도봉구  14.717507  0.139110 -616.501341
# 송파구  10.862599  0.092587 -900.911312

# %%
crime_seoul = pd.read_csv('../csv-data/crime_seoul_2.csv')
len(crime_seoul['구별'].unique())
# Out:
# 25

# %%
cctv_seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 0  강남구  2780       1292    430    584    932  150.619195
# 1  강동구   773        379     99    155    377  166.490765
# 2  강북구   748        369    120    138    204  125.203252
# 3  강서구   884        388    258    184     81  134.793814
# 4  관악구  1496        846    260    390    613  149.290780

# %%
crime_seoul2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 강남구 to 중랑구
# Data columns (total 11 columns):
# Unnamed: 11    25 non-null float64
# 강간 검거          25 non-null int64
# 강간 발생          25 non-null int64
# 강도 검거          25 non-null int64
# 강도 발생          25 non-null int64
# 살인 검거          25 non-null int64
# 살인 발생          25 non-null int64
# 절도 검거          25 non-null int64
# 절도 발생          25 non-null int64
# 폭력 검거          25 non-null int64
# 폭력 발생          25 non-null int64
# dtypes: float64(1), int64(10)
# memory usage: 2.3+ KB

# %%
crime_seoul['절도 발생']=crime_seoul['절도 발생'].str.replace(',','')
crime_seoul['절도 검거']=crime_seoul['절도 검거'].str.replace(',','')
crime_seoul['폭력 발생']=crime_seoul['폭력 발생'].str.replace(',','')
crime_seoul['폭력 검거']=crime_seoul['폭력 검거'].str.replace(',','')

crime_seoul['절도 발생'] = pd.to_numeric(crime_seoul['절도 발생'])
crime_seoul['절도 검거'] = pd.to_numeric(crime_seoul['절도 검거'])
crime_seoul['폭력 발생'] = pd.to_numeric(crime_seoul['폭력 발생'])
crime_seoul['폭력 검거'] = pd.to_numeric(crime_seoul['폭력 검거'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-4b2217849e8b> in <module>
# ----> 1 crime_seoul['절도 발생']=crime_seoul['절도 발생'].str.replace(',','')
#       2 crime_seoul['절도 검거']=crime_seoul['절도 검거'].str.replace(',','')
#       3 crime_seoul['폭력 발생']=crime_seoul['폭력 발생'].str.replace(',','')
#       4 crime_seoul['폭력 검거']=crime_seoul['폭력 검거'].str.replace(',','')
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
crime_seoul2 = pd.pivot_table(crime_seoul, index='구별', aggfunc=sum)

# %%
cctv_seoul2 =cctv_seoul.set_index('구별')
cctv_seoul2
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 구별
# 강남구   2780       1292    430    584    932  150.619195
# 강동구    773        379     99    155    377  166.490765
# 강북구    748        369    120    138    204  125.203252
# 강서구    884        388    258    184     81  134.793814
# 관악구   1496        846    260    390    613  149.290780
# 광진구    707        573     78     53    174   53.228621
# 구로구   1561       1142    173    246    323   64.973730
# 금천구   1015        674     51    269    354  100.000000
# 노원구   1265        542     57    451    516  188.929889
# 도봉구    485        238    159     42    386  246.638655
# 동대문구  1294       1070     23    198    579   74.766355
# 동작구   1091        544    341    103    314  139.338235
# 마포구    574        314    118    169    379  212.101911
# 서대문구   962        844     50     68    292   48.578199
# 서초구   1930       1406    157    336    398   63.371266
# 성동구   1062        730     91    241    265   81.780822
# ...

# %%
data_result['인구수']
# Out:
# 구별
# 강남구     570500.0
# 강동구     453233.0
# 강북구     330192.0
# 강서구     603772.0
# 관악구     525515.0
# 광진구     372164.0
# 구로구     447874.0
# 금천구     255082.0
# 노원구     569384.0
# 도봉구     348646.0
# 동대문구    369496.0
# 동작구     412520.0
# 마포구     389649.0
# 서대문구    327163.0
# 서초구     450310.0
# 성동구     311244.0
# 성북구     461260.0
# 송파구     667483.0
# 양천구     479978.0
# 영등포구    402985.0
# 용산구     244203.0
# 은평구     494388.0
# 종로구     162820.0
# 중구      133240.0
# 중랑구     414503.0
# Name: 인구수, dtype: float64

# %%
## cctv와 범죄율 데이터를 가지고, 다양한 데이터분석을 해보세요!
## 10개 이상 분석!

# %%
len(cctv_seoul['구별'].unique())
# Out:
# 25

# %%
#테이블을 합치는 과정
seoul_data = pd.merge(cctv_seoul2, crime_seoul2,  on='구별')
seoul_data
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년       최근증가율  Unnamed: 11  강간 검거  \
# 구별
# 강남구   2780       1292    430    584    932  150.619195          0.0    349
# 강동구    773        379     99    155    377  166.490765          0.0    123
# 강북구    748        369    120    138    204  125.203252          0.0    126
# 강서구    884        388    258    184     81  134.793814          0.0    191
# 관악구   1496        846    260    390    613  149.290780          0.0    221
# 광진구    707        573     78     53    174   53.228621          0.0    220
# 구로구   1561       1142    173    246    323   64.973730          0.0    164
# 금천구   1015        674     51    269    354  100.000000          0.0    122
# 노원구   1265        542     57    451    516  188.929889          0.0    121
# 도봉구    485        238    159     42    386  246.638655          0.0    106
# 동대문구  1294       1070     23    198    579   74.766355          0.0    146
# ...

# %%
len(seoul_data.index)
# Out:
# 25

# %%
seoul_data.drop(columns=['Unnamed: 11'], inplace=True)
seoul_data.head()
# Out:
#        소계  2013년도 이전  2014년  2015년  2016년       최근증가율  강간 검거  강간 발생  강도 검거  \
# 구별
# 강남구  2780       1292    430    584    932  150.619195    349    449     18
# 강동구   773        379     99    155    377  166.490765    123    156      8
# 강북구   748        369    120    138    204  125.203252    126    153     13
# 강서구   884        388    258    184     81  134.793814    191    262     13
# 관악구  1496        846    260    390    613  149.290780    221    320     14
#
#      강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  폭력 발생
# 구별
# 강남구     21     10     13   1650   3850   3705   4284
# 강동구      6      3      4    789   2366   2248   2712
# 강북구     14      8      7    618   1434   2348   2649
# 강서구     13      8      7   1260   2096   2718   3207
# 관악구     12      8      9    827   2706   2642   3298

# %%
seoul_data = seoul_data.merge(data_result['인구수'], left_on='구별', right_index=True)
# seoul_data.drop(columns=['인구수_x', '인구수_y'], inplace=True)
seoul_data
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년       최근증가율  강간 검거  강간 발생  강도 검거  \
# 구별
# 강남구   2780       1292    430    584    932  150.619195    349    449     18
# 강동구    773        379     99    155    377  166.490765    123    156      8
# 강북구    748        369    120    138    204  125.203252    126    153     13
# 강서구    884        388    258    184     81  134.793814    191    262     13
# 관악구   1496        846    260    390    613  149.290780    221    320     14
# 광진구    707        573     78     53    174   53.228621    220    240     26
# 구로구   1561       1142    173    246    323   64.973730    164    281     11
# 금천구   1015        674     51    269    354  100.000000    122    151      6
# 노원구   1265        542     57    451    516  188.929889    121    197      7
# 도봉구    485        238    159     42    386  246.638655    106    102     10
# 동대문구  1294       1070     23    198    579   74.766355    146    173     13
# ...

# %%
seoul_data.drop(columns=['2013년도 이전', '2014년', '2015년', '2016년', '최근증가율'], inplace=True)

# %%
#합친 테이블에 총 범죄발생수 컬럼 추가
seoul_data['범죄 발생']=seoul_data['강간 발생']+seoul_data['강도 발생']+seoul_data['살인 발생']+seoul_data['절도 발생']+seoul_data['폭력 발생']
seoul_data
# Out:
#         소계  강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  \
# 구별
# 강남구   2780    349    449     18     21     10     13   1650   3850   3705
# 강동구    773    123    156      8      6      3      4    789   2366   2248
# 강북구    748    126    153     13     14      8      7    618   1434   2348
# 강서구    884    191    262     13     13      8      7   1260   2096   2718
# 관악구   1496    221    320     14     12      8      9    827   2706   2642
# 광진구    707    220    240     26     14      4      4   1277   3026   2180
# 구로구   1561    164    281     11     15      6      8    889   2335   2432
# 금천구   1015    122    151      6      6      4      3    888   1567   1776
# 노원구   1265    121    197      7      7     10     10    801   2193   2329
# 도봉구    485    106    102     10      9      3      3    478   1063   1303
# 동대문구  1294    146    173     13     13      5      5    814   1981   2227
# 동작구   1091    139    285      5      9      5      5    661   1865   1587
# ...

# %%
#인구수에 따른 CCTV개수 그래프
np.random.seed(0)
arr = np.random.standard_normal((8, 25))
plt.figure(figsize=(15,10))
plt.scatter(seoul_data['인구수'], seoul_data['소계'], c=arr[1], s=50)

plt.plot(fx, f1(fx), ls ='dashed' ,c='r')
for i in range(len(seoul_data['인구수'])):
    plt.annotate(seoul_data.index[i], (seoul_data['인구수'][i], data_result['소계'][i] + 0.2))
plt.title('인구수에 따른 CCTV개수')
plt.xlabel('인구수')
plt.ylabel('cctv개수')
plt.spring()
plt.show()

# %%
pf2 = np.polyfit(seoul_data['인구수'], seoul_data['범죄 발생'], 1)
pf2
# Out:
# array([5.2688830e-03, 2.9068407e+03])

# %%
f2 = np.poly1d(pf2)
f2
# Out:
# poly1d([5.2688830e-03, 2.9068407e+03])

# %%
fx = np.linspace(100000,700000, 100)
fx
# Out:
# array([100000.        , 106060.60606061, 112121.21212121, 118181.81818182,
#        124242.42424242, 130303.03030303, 136363.63636364, 142424.24242424,
#        148484.84848485, 154545.45454545, 160606.06060606, 166666.66666667,
#        172727.27272727, 178787.87878788, 184848.48484848, 190909.09090909,
#        196969.6969697 , 203030.3030303 , 209090.90909091, 215151.51515152,
#        221212.12121212, 227272.72727273, 233333.33333333, 239393.93939394,
#        245454.54545455, 251515.15151515, 257575.75757576, 263636.36363636,
#        269696.96969697, 275757.57575758, 281818.18181818, 287878.78787879,
#        293939.39393939, 300000.        , 306060.60606061, 312121.21212121,
#        318181.81818182, 324242.42424242, 330303.03030303, 336363.63636364,
#        342424.24242424, 348484.84848485, 354545.45454545, 360606.06060606,
#        366666.66666667, 372727.27272727, 378787.87878788, 384848.48484848,
# ...

# %%
#인구수에 따른 범죄발생수
np.random.seed(0)
arr = np.random.standard_normal((8, 25))
plt.figure(figsize=(15,10))
plt.scatter(seoul_data['인구수'], seoul_data['범죄 발생'], c=arr[1], s=50)

plt.plot(fx, f2(fx), ls ='dashed' ,c='r')
for i in range(len(seoul_data['인구수'])):
    plt.annotate(seoul_data.index[i], (seoul_data['인구수'][i], seoul_data['범죄 발생'][i] + 0.2))
plt.xlabel('인구수')
plt.ylabel('범죄 발생')
plt.title('인구수에 따른 범죄발생수')
plt.xlim(0,700000)
plt.ylim(0,5000)
plt.spring()
axis_range = plt.axis('tight')
plt.show()

# %%
#인구수에 따른 범죄발생수를 보았을때, 중간정도의 양의 상관관계를 보였다

# %%
pf3 = np.polyfit(seoul_data['소계'], seoul_data['범죄 발생'], 1)
pf3
# Out:
# array([7.12802133e-01, 4.21558926e+03])

# %%
f3 = np.poly1d(pf3)
f3
# Out:
# poly1d([7.12802133e-01, 4.21558926e+03])

# %%
fx = np.linspace(0,3000, 10)
fx
# Out:
# array([   0.        ,  333.33333333,  666.66666667, 1000.        ,
#        1333.33333333, 1666.66666667, 2000.        , 2333.33333333,
#        2666.66666667, 3000.        ])

# %%
np.random.seed(0)
arr = np.random.standard_normal((8, 25))
plt.figure(figsize=(15,10))
plt.scatter(seoul_data['소계'], seoul_data['범죄 발생'], c=arr[1], s=50)

plt.plot(fx, f3(fx), ls ='dashed' ,c='r')
for i in range(len(seoul_data['소계'])):
    plt.annotate(seoul_data.index[i], (seoul_data['소계'][i], seoul_data['범죄 발생'][i] + 0.2))
plt.xlabel('cctv 수')
plt.ylabel('범죄 발생')
plt.title('cctv수에 따른 범죄발생수')
plt.spring()
plt.show()

# %%
seoul_data['범죄 검거']=seoul_data['강간 검거']+seoul_data['강도 검거']+seoul_data['살인 검거']+seoul_data['절도 검거']+seoul_data['폭력 검거']
seoul_data['검거율']=seoul_data['범죄 검거']/seoul_data['범죄 발생']*100

# %%
seoul_data
# Out:
#         소계  강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  \
# 구별
# 강남구   2780    349    449     18     21     10     13   1650   3850   3705
# 강동구    773    123    156      8      6      3      4    789   2366   2248
# 강북구    748    126    153     13     14      8      7    618   1434   2348
# 강서구    884    191    262     13     13      8      7   1260   2096   2718
# 관악구   1496    221    320     14     12      8      9    827   2706   2642
# 광진구    707    220    240     26     14      4      4   1277   3026   2180
# 구로구   1561    164    281     11     15      6      8    889   2335   2432
# 금천구   1015    122    151      6      6      4      3    888   1567   1776
# 노원구   1265    121    197      7      7     10     10    801   2193   2329
# 도봉구    485    106    102     10      9      3      3    478   1063   1303
# 동대문구  1294    146    173     13     13      5      5    814   1981   2227
# 동작구   1091    139    285      5      9      5      5    661   1865   1587
# ...

# %%
plt.figure(figsize=(15,10))
seoul_data['검거율'].plot(kind='barh', grid=True)
plt.title('구별 범죄 검거율')
# Out:
# Text(0.5, 1.0, '구별 범죄 검거율')

# %%
seoul_data2 = seoul_data[['소계', '인구수', '범죄 발생', '검거율']]
seoul_data2
# Out:
#         소계       인구수  범죄 발생        검거율
# 구별
# 강남구   2780  570500.0   8617  66.519670
# 강동구    773  453233.0   5244  60.469108
# 강북구    748  330192.0   4257  73.126615
# 강서구    884  603772.0   5585  75.022381
# 관악구   1496  525515.0   6345  58.502758
# 광진구    707  372164.0   5909  62.734811
# 구로구   1561  447874.0   5646  62.026213
# 금천구   1015  255082.0   3781  73.948691
# 노원구   1265  569384.0   5130  63.703704
# 도봉구    485  348646.0   2664  71.321321
# 동대문구  1294  369496.0   4720  67.902542
# 동작구   1091  412520.0   4074  58.836524
# 마포구    574  389649.0   5854  61.445166
# 서대문구   962  327163.0   4029  64.010921
# 서초구   1930  450310.0   5444  63.372520
# 성동구   1062  311244.0   3358  63.222156
# 성북구   1464  461260.0   4154  65.695715
# 송파구    618  667483.0   6778  60.681617
# 양천구   2034  479978.0   4528  62.168728
# 영등포구   904  402985.0   6867  60.492209
# 용산구   1624  244203.0   3820  65.000000
# 은평구   1873  494388.0   4745  66.743941
# 종로구   1002  162820.0   4705  62.550478
# ...

# %%
seoul_data2.corr()
# Out:
#              소계       인구수     범죄 발생       검거율
# 소계     1.000000  0.306342  0.312748 -0.038879
# 인구수    0.306342  1.000000  0.540950 -0.016648
# 범죄 발생  0.312748  0.540950  1.000000 -0.307349
# 검거율   -0.038879 -0.016648 -0.307349  1.000000

# %%
# 소계-인구수 = 0.3, 소계 - 범죄발생 = 0.3, 소계-검거율 = -0.03
# 인구수-범죄발생=0.54 인구수-검거율= 0.01
# 검거율-범죄발생 = -0.3

# %%
plt.matshow(seoul_data2.corr())
plt.colorbar(shrink=0.8, aspect=10)
plt.show()

# %%
sns.pairplot(seoul_data2.corr())
# Out:
# C:\Users\hi\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hi\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
pf4 = np.polyfit(seoul_data['소계'], seoul_data['검거율'], 1)
pf4
# Out:
# array([-3.24112901e-04,  6.49602822e+01])

# %%
f4 = np.poly1d(pf4)
f4
# Out:
# poly1d([-3.24112901e-04,  6.49602822e+01])

# %%
fx = np.linspace(400,3000, 10)
fx
# Out:
# array([ 400.        ,  688.88888889,  977.77777778, 1266.66666667,
#        1555.55555556, 1844.44444444, 2133.33333333, 2422.22222222,
#        2711.11111111, 3000.        ])

# %%
np.random.seed(0)
arr = np.random.standard_normal((8, 25))
plt.figure(figsize=(15,10))
plt.scatter(seoul_data['소계'], seoul_data['검거율'], c=arr[1], s=50)

plt.plot(fx, f4(fx), ls ='dashed' ,c='r')
for i in range(len(seoul_data['소계'])):
    plt.annotate(seoul_data.index[i], (seoul_data['소계'][i], seoul_data['검거율'][i] + 0.2))
plt.xlabel('소계')
plt.ylabel('검거율')
plt.title('cctv수에 따른 검거율')
plt.xlim(400,3000)
plt.ylim(55,80)
plt.spring()
plt.show()

# %%
#insight
## 인구수에 따른 범죄발생수를 보았을때, 중간정도의 양의 상관관계를 보였다 (0.54)
## cctv의 개수는 인구수 그리고 범죄발생수와  0.3정도의 아주 작은 상관관계를 가져, 인구수, 범죄발생수와는 다른 기준으로 cctv가 설치되는것을 볼 수 있다.
## 하지만 인구수와 범죄발생수는 0.54로 중간정도의 상관관계를 가져, 인구수와 범죄발생수를 기준으로 잡아 더 설치를 해도 괜찮을것 같다.
## 하지만 사실상 cctv의 개수는 검거율과는 -0.03정도의 매우 낮은 상관관계를 가져 범죄자 검거 자체에는 아에 도움을 주지 못하는 것으로 분석됐다.
## 강남구에는 다른 구에 비해 많은 cctv가 설치되었지만, 다른 구에 비해 월등히 범죄수가 많았고, 검거율은 중간정도로 나타났다.
## 검거율과 범죄발생율은 -0.3으로 작은 음의 상관관계를 가지고 있다.
## 인구수에 따른 범죄발생수를 보았을대, 도봉구 주민들이 가장 착한것으로 보이고 
## 송파구 주민들이 가장 범죄율이 높은것으로 보인다.
## 강서구가 가장 검거율이 높은것으로 보인다
## 도봉구는 cctv개수가 가장 작지만 검거율은 상위권에 속한다.
