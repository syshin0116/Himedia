# %%
import nltk

# %%
with open("data.txt") as f:
    data = f.read()

# %%
data
# Out:
# 'Lightning\'s medium-duty zero-emission fleet offerings now include Level 2 and Level 4 autonomous vehicle capability Perrone\'s vehicle-agnostic TONY® AV system is available for all Lightning vehicle orders Perrone\'s proven Lidar-centric autonomous technology a differentiating factor Lightning eMotors  ZEV -13.2% + Free Alerts , a leading provider of zero-emission medium-duty commercial vehicles and electric vehicle technology for fleets, and Perrone Robotics have partnered to offer Class 3 - 7 commercial fleet customers self-driving, electric fleet vehicles that can be deployed for a wide range of dedicated uses.  This press release features multimedia. View the full release here: https://www.businesswire.com/news/home/20220509005106/en/  LIVE NOW ON YOUTUBE:\xa0How Pro Traders Profit During a Market Crash & How to Be Ready to Buy the Next Dip\xa0Click Here Now to WATCH >>\xa0    361.8K TaxChat - Get Ready For Tax Season Next Stay.   A Lightning electric van equipped with Perrone Robotics\' autonomous driving system goes through its paces at Perrone\'s proving ground in Crozet, Virginia (Photo: Lightning eMotors)  The partnership expands Lightning\'s zero-emissions EV platform offerings to include Perrone\'s AV-powered technology, TONY®, a vehicle-independent retrofit kit designed to enable vehicles to transport people and goods in geo-fenced and dedicated driving routes. Vehicles equipped with Perrone\'s self-driving technology embedded into Lightning\'s vehicles for both cargo and passenger uses can be ordered immediately.  "We were looking for partners who could deliver autonomous capabilities to our customers today, and in the future — and that\'s what Perrone offers," Lightning eMotors CEO Tim Reeser said. "We offer perhaps the widest range of electric commercial vehicles in North America, and now we have an autonomous vehicle solution for our products, ranging from ambulances to campus shuttles and other commercial applications."  PIDC, Philadelphia\'s public-private economic development corporation, is the first Lightning eMotors customer to purchase a self-driving, all-electric shuttle powered by Perrone\'s TONY AV kit. Pennsylvania\'s first AV shuttle will provide transportation services to visitors and employees within the Philadelphia Navy Yard, a 1,200-acre dynamic, urban development centrally located in the popular waterfront business campus. Lightning and Perrone are in active discussions with a number of other potential customers as well.  Perrone is a leading provider of AV technology and turnkey vehicle solutions. The company holds a Pioneer Patent for its "MAX" general purpose robotics operating system, which is the backbone of its TONY solution. Together with MAX, TONY is one of the most flexible and adaptable AV solutions available in the current market. Perrone\'s AV retrofit kit can be integrated into new vehicles and can also be integrated into existing, repowered vehicles.  "A lot of electric vehicle manufacturers are focused on just one vehicle size, and in many cases it\'s a bespoke custom platform," Perrone Robotics, Inc. founder and CEO Paul Perrone said. "But that\'s not how we operate at Perrone – our partnership with Lightning is an example of how we want to make a bigger impact. Lightning\'s wide range of vehicles is aligned perfectly with the way we want to help foster the widespread adoption of self-driving technology."  Initially, Lightning will deploy Perrone\'s technology into two product categories, including fully autonomous Level 4 application environments with dedicated routes such as college campuses, and Level 2 applications for high-end visual and safety features for commercial vehicles. Currently, Level 4 vehicles can only operate in geo-fenced areas, but demand for this use is rising as campuses, logistics yards, downtown business districts, resorts, and other organizations and municipalities seek EV/AV solutions.  Level 2 autonomous vehicles are also seeing rising demand, espec ...

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %%
print(sent_tokenize(data[:1000])[1])
# Out:
# This press release features multimedia.

# %%
word_tokenize(data[50:100])
# Out:
# ['ngs',
#  'now',
#  'include',
#  'Level',
#  '2',
#  'and',
#  'Level',
#  '4',
#  'autonomous',
#  'veh']

# %%
from nltk.tokenize import RegexpTokenizer
retokenize = RegexpTokenizer("[\w]+")
retokenize.tokenize(data)
# Out:
# ['Lightning',
#  's',
#  'medium',
#  'duty',
#  'zero',
#  'emission',
#  'fleet',
#  'offerings',
#  'now',
#  'include',
#  'Level',
#  '2',
#  'and',
#  'Level',
#  '4',
#  'autonomous',
#  'vehicle',
#  'capability',
#  'Perrone',
#  's',
#  'vehicle',
#  'agnostic',
#  'TONY',
#  'AV',
#  'system',
#  'is',
#  'available',
#  'for',
#  'all',
#  'Lightning',
#  'vehicle',
#  'orders',
#  'Perrone',
#  's',
#  'proven',
#  'Lidar',
#  'centric',
#  'autonomous',
#  'technology',
#  'a',
#  'differentiating',
#  'factor',
#  'Lightning',
#  'eMotors',
#  'ZEV',
#  '13',
#  '2',
#  'Free',
#  'Alerts',
#  'a',
#  'leading',
#  'provider',
#  'of',
#  'zero',
#  'emission',
#  'medium',
#  'duty',
#  'commercial',
#  'vehicles',
#  'and',
#  'electric',
#  'vehicle',
#  'technology',
#  'for',
#  'fleets',
#  'and',
#  'Perrone',
#  'Robotics',
#  'have',
#  'partnered',
#  'to',
#  'offer',
#  'Class',
#  '3',
#  '7',
#  'commercial',
#  'fleet',
#  'customers',
#  'self',
#  'driving',
#  'electric',
#  'fleet',
#  'vehicles',
#  'that',
#  'can',
#  'be',
#  'deployed',
#  'for',
#  'a',
#  'wide',
#  'range',
#  'of',
#  'dedicated',
#  'uses',
#  'This',
#  'press',
#  'release',
#  'features',
#  'multimedia',
#  'View',
#  'the',
#  'full',
#  'release',
#  'here',
#  'https',
#  'www',
#  'businesswire',
#  'com',
#  'news',
#  'home',
#  '20220509005106',
#  'en',
#  'LIVE',
#  'NOW',
#  'ON',
#  'YOUTUBE',
#  'How',
#  'Pro',
#  'Traders',
#  'Profit',
#  'During',
#  'a',
#  'Market',
#  'Crash',
#  'How',
#  'to',
#  'Be',
#  'Ready',
#  'to',
#  'Buy',
#  'the',
#  'Next',
#  'Dip',
#  'Click',
#  'Here',
#  'Now',
#  'to',
#  'WATCH',
#  '361',
#  '8K',
#  'TaxChat',
#  'Get',
#  'Ready',
#  'For',
#  'Tax',
#  'Season',
#  'Next',
#  'Stay',
#  'A',
#  'Lightning',
#  'electric',
#  'van',
#  'equipped',
#  'with',
#  'Perrone',
#  'Robotics',
#  'autonomous',
#  'driving',
#  'system',
#  'goes',
#  'through',
#  'its',
#  'paces',
#  'at',
#  'Perrone',
#  's',
#  'proving',
#  'ground',
#  'in',
#  'Crozet',
#  'Virginia',
#  'Photo',
#  'Lightning',
#  'eMotors',
#  'The',
#  'partnership',
#  'expands',
#  'Lightning',
#  's',
#  'zero',
#  'emissions',
#  'EV',
#  'platform',
#  'offerings',
#  'to',
#  'include',
#  'Perrone',
#  's',
#  'AV',
#  'powered',
#  'technology',
#  'TONY',
#  'a',
#  'vehicle',
#  'independent',
#  'retrofit',
#  'kit',
#  'designed',
#  'to',
#  'enable',
#  'vehicles',
#  'to',
#  'transport',
#  'people',
#  'and',
#  'goods',
#  'in',
#  'geo',
#  'fenced',
#  'and',
#  'dedicated',
#  'driving',
#  'routes',
#  'Vehicles',
#  'equipped',
#  'with',
#  'Perrone',
#  's',
#  'self',
#  'driving',
#  'technology',
#  'embedded',
#  'into',
#  'Lightning',
#  's',
#  'vehicles',
#  'for',
#  'both',
#  'cargo',
#  'and',
#  'passenger',
#  'uses',
#  'can',
#  'be',
#  'ordered',
#  'immediately',
#  'We',
#  'were',
#  'looking',
#  'for',
#  'partners',
#  'who',
#  'could',
#  'deliver',
#  'autonomous',
#  'capabilities',
#  'to',
#  'our',
#  'customers',
#  'today',
#  'and',
#  'in',
#  'the',
#  'future',
#  'and',
#  'that',
#  's',
#  'what',
#  'Perrone',
#  'offers',
#  'Lightning',
#  'eMotors',
#  'CEO',
#  'Tim',
#  'Reeser',
#  'said',
#  'We',
#  'offer',
#  'perhaps',
#  'the',
#  'widest',
#  'range',
#  'of',
#  'electric',
#  'commercial',
#  'vehicles',
#  'in',
#  'North',
#  'America',
#  'and',
#  'now',
#  'we',
#  'have',
#  'an',
#  'autonomous',
#  'vehicle',
#  'solution',
#  'for',
#  'our',
#  'products',
#  'ranging',
#  'from',
#  'ambulances',
#  'to',
#  'campus',
#  'shuttles',
#  'and',
#  'other',
#  'commercial',
#  'applications',
#  'PIDC',
#  'Philadelphia',
#  's',
#  'public',
#  'private',
#  'economic',
#  'development',
#  'corporation',
#  'is',
#  'the',
#  'first',
#  'Lightning',
#  'eMotors',
#  'customer',
#  'to',
#  'purchase',
#  'a',
#  'self',
#  'driving',
#  'all',
#  'electric',
#  'shuttle',
#  'powered',
#  'by',
#  'Perrone',
#  's',
#  'TONY',
#  'AV',
#  'kit',
#  'Pennsylvania',
#  's',
#  'first',
#  'AV',
#  'shuttle',
#  'will',
#  'provide',
#  'transportation',
#  'services',
#  'to',
#  'visitors',
#  'and',
#  'employees',
#  'within',
#  'the',
#  'Philadelphia',
#  'Navy',
#  'Yard',
#  'a',
#  '1',
#  '200',
#  'acre',
#  'dynamic',
#  'urban',
#  'development',
#  'centrally',
#  'located',
#  'in',
#  'the',
#  'popular',
#  'waterfront',
#  'business',
#  'campus',
#  'Lightning',
#  'and',
#  'Perrone',
#  'are',
#  'in',
#  'active',
#  'discussions',
#  'with',
#  'a',
#  'number',
#  'of',
#  'other',
#  'potential',
#  'customers',
#  'as',
#  'well',
#  'Perrone',
#  'is',
#  'a',
#  'leading',
#  'provider',
#  'of',
#  'AV',
#  'technology',
#  'and',
#  'turnkey',
#  'vehicle',
#  'solutions',
#  'The',
#  'company',
#  'holds',
#  'a',
#  'Pioneer',
#  'Patent',
#  'for',
#  'its',
#  'MAX',
#  'general',
#  'purpose',
#  'robotics',
#  'operating',
#  'system',
#  'which',
#  'is',
#  'the',
#  'backbone',
#  'of',
#  'its',
#  'TONY',
#  'solution',
#  'Together',
#  'with',
#  'MAX',
#  'TONY',
#  'is',
#  'one',
#  'of',
#  'the',
#  'most',
#  'flexible',
#  'and',
#  'adaptable',
#  'AV',
#  'solutions',
#  'available',
#  'in',
#  'the',
#  'current',
#  'market',
#  'Perrone',
#  's',
#  'AV',
#  'retrofit',
#  'kit',
#  'can',
#  'be',
#  'integrated',
#  'into',
#  'new',
#  'vehicles',
#  'and',
#  'can',
#  'also',
#  'be',
#  'integrated',
#  'into',
#  'existing',
#  'repowered',
#  'vehicles',
#  'A',
#  'lot',
#  'of',
#  'electric',
#  'vehicle',
#  'manufacturers',
#  'are',
#  'focused',
#  'on',
#  'just',
#  'one',
#  'vehicle',
#  'size',
#  'and',
#  'in',
#  'many',
#  'cases',
#  'it',
#  's',
#  'a',
#  'bespoke',
#  'custom',
#  'platform',
#  'Perrone',
#  'Robotics',
#  'Inc',
#  'founder',
#  'and',
#  'CEO',
#  'Paul',
#  'Perrone',
#  'said',
#  'But',
#  'that',
#  's',
#  'not',
#  'how',
#  'we',
#  'operate',
#  'at',
#  'Perrone',
#  'our',
#  'partnership',
#  'with',
#  'Lightning',
#  'is',
#  'an',
#  'example',
#  'of',
#  'how',
#  'we',
#  'want',
#  'to',
#  'make',
#  'a',
#  'bigger',
#  'impact',
#  'Lightning',
#  's',
#  'wide',
#  'range',
#  'of',
#  'vehicles',
#  'is',
#  'aligned',
#  'perfectly',
#  'with',
#  'the',
#  'way',
#  'we',
#  'want',
#  'to',
#  'help',
#  'foster',
#  'the',
#  'widespread',
#  'adoption',
#  'of',
#  'self',
#  'driving',
#  'technology',
#  'Initially',
#  'Lightning',
#  'will',
#  'deploy',
#  'Perrone',
#  's',
#  'technology',
#  'into',
#  'two',
#  'product',
#  'categories',
#  'including',
#  'fully',
#  'autonomous',
#  'Level',
#  '4',
#  'application',
#  'environments',
#  'with',
#  'dedicated',
#  'routes',
#  'such',
#  'as',
#  'college',
#  'campuses',
#  'and',
#  'Level',
#  '2',
#  'applications',
#  'for',
#  'high',
#  'end',
#  'visual',
#  'and',
#  'safety',
#  'features',
#  'for',
#  'commercial',
#  'vehicles',
#  'Currently',
#  'Level',
#  '4',
#  'vehicles',
#  'can',
#  'only',
#  'operate',
#  'in',
#  'geo',
#  'fenced',
#  'areas',
#  'but',
#  'demand',
#  'for',
#  'this',
#  'use',
#  'is',
#  'rising',
#  'as',
#  'campuses',
#  'logistics',
#  'yards',
#  'downtown',
#  'business',
#  'districts',
#  'resorts',
#  'and',
#  'other',
#  'organizations',
#  'and',
#  'municipalities',
#  'seek',
#  'EV',
#  'AV',
#  'solutions',
#  'Level',
#  '2',
#  'autonomous',
#  'vehicles',
#  'are',
#  'also',
#  'seeing',
#  'rising',
#  'demand',
#  'especially',
#  'for',
#  'transit',
#  'vehicle',
#  'operators',
#  'who',
#  'can',
#  'benefit',
#  'from',
#  'the',
#  'state',
#  'of',
#  'the',
#  'art',
#  'safety',
#  'features',
#  'including',
#  'lane',
#  'keeping',
#  'capability',
#  'adaptive',
#  'cruise',
#  'control',
#  'and',
#  'forward',
#  'collision',
#  'avoidance',
#  'All',
#  'of',
#  'these',
#  'features',
#  'are',
#  'now',
#  'available',
#  'among',
#  'Lightning',
#  's',
#  'platform',
#  'offerings',
#  'and',
#  'will',
#  'be',
#  'powered',
#  'by',
#  'lidar',
#  'technology',
#  'fused',
#  'with',
#  'radar',
#  'to',
#  'add',
#  'an',
#  'additional',
#  'layer',
#  'of',
#  'redundancy',
#  'that',
#  's',
#  'important',
#  'for',
#  'all',
#  'Lightning',
#  'applications',
#  'Our',
#  'customers',
#  'are',
#  'telling',
#  'us',
#  'they',
#  'want',
#  'this',
#  'technology',
#  'and',
#  'now',
#  'we',
#  'can',
#  'deliver',
#  'it',
#  'These',
#  'vehicles',
#  'are',
#  'ideal',
#  'for',
#  'college',
#  'campuses',
#  'downtown',
#  'business',
#  'districts',
#  'vacation',
#  'resorts',
#  'and',
#  'for',
#  'large',
#  'logistics',
#  'yards',
#  'Reeser',
#  'said',
#  'And',
#  'thanks',
#  'to',
#  'our',
#  'partnership',
#  'with',
#  'Perrone',
#  'we',
#  'stand',
#  'alone',
#  'as',
#  'the',
#  'only',
#  'all',
#  'electric',
#  'commercial',
#  'vehicle',
#  'provider',
#  'that',
#  'can',
#  'offer',
#  'Class',
#  '3',
#  '7',
#  'medium',
#  'duty',
#  'vehicles',
#  'that',
#  'are',
#  'fully',
#  'autonomous',
#  'and',
#  'are',
#  'certified',
#  'by',
#  'the',
#  'departments',
#  'of',
#  'transportation',
#  'local',
#  'transit',
#  'agencies',
#  'and',
#  'other',
#  'commercial',
#  'organizations',
#  'A',
#  'video',
#  'of',
#  'a',
#  'Lightning',
#  'electric',
#  'van',
#  'equipped',
#  'with',
#  'Perrone',
#  'Robotics',
#  'autonomous',
#  'system',
#  'can',
#  'be',
#  'found',
#  'here',
#  'https',
#  'link',
#  'assetfile',
#  'io',
#  '4njY9uifJsHAg1BPHcR52q',
#  'mp4',
#  'About',
#  'Lightning',
#  'eMotors',
#  'Lightning',
#  'eMotors',
#  'ZEV',
#  '13',
#  '2',
#  'Free',
#  'Alerts',
#  'based',
#  'in',
#  'Loveland',
#  'Colorado',
#  'has',
#  'been',
#  'providing',
#  'specialized',
#  'and',
#  'sustainable',
#  'fleet',
#  'solutions',
#  'since',
#  '2009',
#  'deploying',
#  'complete',
#  'zero',
#  'emission',
#  'vehicle',
#  'ZEV',
#  'solutions',
#  'for',
#  'commercial',
#  'fleets',
#  'since',
#  '2018',
#  'including',
#  'Class',
#  '3',
#  'cargo',
#  'and',
#  'passenger',
#  'vans',
#  'Class',
#  '4',
#  'and',
#  '5',
#  'cargo',
#  'vans',
#  'and',
#  'shuttle',
#  'buses',
#  'Class',
#  '4',
#  'Type',
#  'A',
#  'school',
#  'buses',
#  'Class',
#  '6',
#  'work',
#  'trucks',
#  'Class',
#  '7',
#  'city',
#  'buses',
#  'and',
#  'Class',
#  'A',
#  'motor',
#  'coaches',
#  'The',
#  'Lightning',
#  'eMotors',
#  'team',
#  'designs',
#  'engineers',
#  'customizes',
#  'and',
#  'manufactures',
#  'zero',
#  'emission',
#  'vehicles',
#  'to',
#  'support',
#  'the',
#  'wide',
#  'array',
#  'of',
#  'fleet',
#  'customer',
#  'needs',
#  'including',
#  'school',
#  'buses',
#  'and',
#  'ambulances',
#  'with',
#  'a',
#  'full',
#  'suite',
#  'of',
#  'control',
#  'software',
#  'telematics',
#  'analytics',
#  'and',
#  'charging',
#  'solutions',
#  'to',
#  'simplify',
#  'the',
#  'buying',
#  'and',
#  'ownership',
#  'experience',
#  'and',
#  'maximize',
#  'uptime',
#  'and',
#  'energy',
#  'efficiency',
#  'Lightning',
#  'eMotors',
#  'also',
#  'offers',
#  'charging',
#  'technologies',
#  'and',
#  'charging',
#  'as',
#  'a',
#  'service',
#  'CaaS',
#  'to',
#  'commercial',
#  'and',
#  'government',
#  'fleets',
#  'via',
#  'its',
#  'Lightning',
#  'Energy',
#  'division',
#  'To',
#  'learn',
#  'more',
#  'visit',
#  'https',
#  'lightningemotors',
#  'com',
#  'About',
#  'Perrone',
#  'Robotics',
#  'Inc',
#  'Perrone',
#  'is',
#  'a',
#  'leading',
#  'provider',
#  'of',
#  'fully',
#  'automated',
#  'vehicle',
#  'systems',
#  'The',
#  'company',
#  'delivers',
#  'mobility',
#  'excellence',
#  'via',
#  'TONY',
#  'short',
#  'for',
#  'TO',
#  'Navigate',
#  'You',
#  'a',
#  'vehicle',
#  'independent',
#  'retrofit',
#  'kit',
#  'for',
#  'use',
#  'in',
#  'the',
#  'automated',
#  'transit',
#  'of',
#  'people',
#  'and',
#  'goods',
#  'in',
#  'geo',
#  'fenced',
#  'and',
#  'localized',
#  'operations',
#  'TONY',
#  'embeds',
#  'inside',
#  'any',
#  'vehicle',
#  'type',
#  'or',
#  'model',
#  'for',
#  'any',
#  'job',
#  'application',
#  'to',
#  'provide',
#  'a',
#  'complete',
#  'artificial',
#  'driver',
#  'solution',
#  'that',
#  'brings',
#  ...]

# %%
from nltk.stem import PorterStemmer, LancasterStemmer
from nltk.tag import pos_tag

# %%
tagged_list = pos_tag(word_tokenize(data))

# %%
nouns_list = [t[0] for t in tagged_list if t[1] == "NN"]
nouns_list
# Out:
# ['zero-emission',
#  'fleet',
#  'vehicle',
#  'capability',
#  'system',
#  'vehicle',
#  'technology',
#  'factor',
#  '%',
#  'provider',
#  'zero-emission',
#  'vehicle',
#  'technology',
#  'fleet',
#  'fleet',
#  'range',
#  'press',
#  'release',
#  'release',
#  'https',
#  'YOUTUBE',
#  'Profit',
#  'van',
#  'system',
#  'ground',
#  'partnership',
#  'platform',
#  'technology',
#  'retrofit',
#  'kit',
#  'driving',
#  'technology',
#  'cargo',
#  'passenger',
#  'today',
#  'future',
#  '—',
#  'range',
#  'vehicle',
#  'solution',
#  'development',
#  'corporation',
#  'customer',
#  'shuttle',
#  'kit',
#  'shuttle',
#  'transportation',
#  'dynamic',
#  'development',
#  'waterfront',
#  'business',
#  'campus',
#  'number',
#  'provider',
#  'technology',
#  'vehicle',
#  'company',
#  'purpose',
#  'system',
#  'backbone',
#  'solution',
#  'market',
#  'retrofit',
#  'kit',
#  'lot',
#  'vehicle',
#  'vehicle',
#  'size',
#  'bespoke',
#  'custom',
#  'platform',
#  'founder',
#  'partnership',
#  'example',
#  'impact',
#  'range',
#  'way',
#  'adoption',
#  'technology',
#  'technology',
#  'product',
#  'application',
#  'college',
#  'safety',
#  'demand',
#  'use',
#  'downtown',
#  'business',
#  'demand',
#  'transit',
#  'vehicle',
#  'safety',
#  'capability',
#  'cruise',
#  'control',
#  'collision',
#  'avoidance',
#  'platform',
#  'lidar',
#  'technology',
#  'radar',
#  'layer',
#  'redundancy',
#  'technology',
#  'college',
#  'downtown',
#  'business',
#  'vacation',
#  'partnership',
#  'vehicle',
#  'provider',
#  'transportation',
#  'transit',
#  'video',
#  'van',
#  'system',
#  'https',
#  '//link.assetfile.io/4njY9uifJsHAg1BPHcR52q.mp4',
#  '%',
#  'fleet',
#  'zero-emission-vehicle',
#  'cargo',
#  'passenger',
#  'cargo',
#  'school',
#  'work',
#  'city',
#  'motor',
#  'team',
#  'zero-emission',
#  'array',
#  'fleet',
#  'customer',
#  'school',
#  'suite',
#  'control',
#  'software',
#  'buying',
#  'ownership',
#  'experience',
#  'energy',
#  'efficiency',
#  'charging',
#  'service',
#  'government',
#  'division',
#  'visit',
#  'https',
#  '//lightningemotors.com',
#  'provider',
#  'vehicle',
#  'company',
#  'mobility',
#  'excellence',
#  'vehicle',
#  'kit',
#  'use',
#  'transit',
#  'vehicle',
#  'type',
#  'model',
#  'job',
#  'application',
#  'driver',
#  'solution',
#  'autonomy',
#  'safety',
#  'framework',
#  'production',
#  'transportation',
#  'enhance',
#  'safety',
#  'zero-emission',
#  'vehicle',
#  'deployment',
#  'company',
#  'portfolio',
#  'turnkey',
#  'kit',
#  'www.perronerobotics.com',
#  'press',
#  'release',
#  'meaning',
#  'future',
#  'business',
#  'fact',
#  'addition',
#  'estimate',
#  'plan',
#  'predict',
#  'project',
#  'absence',
#  'statement',
#  'press',
#  'release',
#  'management',
#  'light',
#  'experience',
#  'perception',
#  'assurance',
#  'press',
#  'release',
#  'i',
#  'business',
#  'performance',
#  'ii',
#  'ability',
#  'business',
#  'strategy',
#  'demand',
#  'revenue',
#  'iii',
#  'shortage',
#  'iv',
#  'severity',
#  'magnitude',
#  'duration',
#  'pandemic',
#  'business',
#  'supply',
#  'position',
#  'economy',
#  'v',
#  'market',
#  'state',
#  'government',
#  'vehicle',
#  'market',
#  'regulation',
#  'vi',
#  'size',
#  'growth',
#  'vii',
#  'mix',
#  'viii',
#  'market',
#  'acceptance',
#  'product',
#  'catalyst',
#  'ix',
#  'rate',
#  'vehicle',
#  'time',
#  'time',
#  'environment',
#  'time',
#  'time',
#  'reliance',
#  'guarantee',
#  'performance',
#  'performance',
#  'prove',
#  'incorrect',
#  'obligation',
#  'result',
#  'information',
#  '/PRNewswire/',
#  '%',
#  'leader',
#  'today',
#  'member',
#  'management',
#  'board',
#  'member',
#  'expertise',
#  'experience',
#  'industry',
#  'heart',
#  'decision',
#  'making',
#  'world',
#  'mobility',
#  'expertise',
#  'area',
#  'industry',
#  'business',
#  'design',
#  'engineering',
#  'radar',
#  'industry',
#  'safer',
#  'future',
#  'YOUTUBE',
#  'Profit',
#  'development',
#  'vehicle',
#  'concept',
#  'generation',
#  'mobility',
#  'flagship-product',
#  'role',
#  'position',
#  'building',
#  'team',
#  'company',
#  'winner',
#  'technology',
#  'solution',
#  'nothing',
#  'delivery',
#  'driver',
#  'achievement',
#  'driving',
#  'team',
#  'leadership',
#  'revolution',
#  'company',
#  'technology',
#  '%',
#  'leader',
#  'radar',
#  'revolution',
#  'today',
#  'way',
#  'autonomous-driving',
#  'imaging',
#  'radar',
#  'radar',
#  'market',
#  'sensor',
#  'autonomy',
#  'company',
#  'ground',
#  'array',
#  'safety',
#  'sensing',
#  'perception',
#  'leader',
#  'radar',
#  'market',
#  'market',
#  'office',
#  'press',
#  'release',
#  'meaning',
#  'estimate',
#  'intend',
#  'plan',
#  'anticipate',
#  'project',
#  'strategy',
#  'future',
#  'project',
#  'result',
#  'future',
#  'market',
#  'position',
#  'market',
#  'risk',
#  'risk',
#  'report',
#  'reliance',
#  'date',
#  'obligation',
#  'date',
#  'law',
#  'regulation',
#  'Vehicle',
#  'Market',
#  'report',
#  'offering',
#  'vehicle',
#  'market',
#  '%',
#  'market',
#  'revenue',
#  'rate',
#  'forecast',
#  'period',
#  'increase',
#  'demand',
#  'region',
#  'YOUTUBE',
#  'Profit',
#  'addition',
#  'vehicle',
#  'market',
#  'growth',
#  'infrastructure',
#  'investment',
#  'increase',
#  'collaboration',
#  'vehicle',
#  'emergence',
#  'business',
#  'instance',
#  'expansion',
#  'business',
#  'foundation',
#  'center',
#  'excellence',
#  'partnership',
#  'agreement',
#  'subsidiary',
#  'company',
#  'taxi',
#  'e-Hail',
#  'end',
#  'addition',
#  'adoption',
#  'vehicle',
#  'taxis',
#  'convenience',
#  'instance',
#  'on-demand',
#  'model',
#  'service',
#  'platform',
#  'environment',
#  'shift',
#  'market',
#  'forecast',
#  'period',
#  'vehicle',
#  'market',
#  'report',
#  'level',
#  'automation',
#  'component',
#  'application',
#  'propulsion',
#  'type',
#  'vehicle',
#  'type',
#  'region',
#  'level',
#  'automation',
#  'level',
#  'level',
#  'level',
#  'automation',
#  'component',
#  'hardware',
#  'software',
#  'service',
#  'application',
#  'defense',
#  'transportation',
#  'construction',
#  'propulsion',
#  'type',
#  'basis',
#  'vehicle',
#  'type',
#  'passenger',
#  'car',
#  'vehicle',
#  'wise',
#  'market',
#  'improvement',
#  'safety',
#  'reduction',
#  'traffic',
#  'congestion',
#  'growth',
#  'infrastructure',
#  'transition',
#  'ownership',
#  'mobility-as-a-service',
#  'market',
#  'growth',
#  'globe',
#  'manufacturing',
#  'cost',
#  'management',
#  'market',
#  'growth',
#  'world',
#  'development',
#  'government',
#  'market',
#  'growth',
#  'forecast',
#  'period',
#  'segment',
#  'growth',
#  'forecast',
#  'period',
#  'application',
#  'segment',
#  'growth',
#  'future',
#  'basis',
#  'drive',
#  'type',
#  'segment',
#  'growth',
#  'future',
#  'basis',
#  'vehicle',
#  'type',
#  'vehicle',
#  'segment',
#  'vehicle',
#  'market',
#  'Impact',
#  'crisis',
#  'uncertainty',
#  'market',
#  'business',
#  'growth',
#  'panic',
#  'customer',
#  'border',
#  'movement',
#  'transportation',
#  'business',
#  'outlook',
#  'health',
#  'crisis',
#  'service',
#  'market',
#  'fall',
#  'demand',
#  'cash',
#  'usage',
#  'risk',
#  'contamination',
#  'scenario',
#  'world',
#  'track',
#  'restriction',
#  'recovery',
#  'product',
#  'sector',
#  'influence',
#  'vehicle',
#  'market',
#  'key',
#  'vehicle',
#  'market']

# %%
from nltk import Text

# %%
text = Text(retokenize.tokenize(data))
text
# Out:
# <Text: Lightning s medium duty zero emission fleet offerings...>

# %%
text.plot(20)

# %%
from nltk import FreqDist

# %%
data_tokens = pos_tag(retokenize.tokenize(data))
fd_names = FreqDist(data_tokens)
fd_names.most_common(10)
# Out:
# [(('and', 'CC'), 138),
#  (('the', 'DT'), 138),
#  (('of', 'IN'), 94),
#  (('to', 'TO'), 79),
#  (('in', 'IN'), 57),
#  (('a', 'DT'), 49),
#  (('is', 'VBZ'), 37),
#  (('for', 'IN'), 35),
#  (('vehicle', 'NN'), 32),
#  (('autonomous', 'JJ'), 28)]

# %%
stopwords = ["and", "the", "of", "to", "in", "a", 'is', 'for']
data_tokens2 = [w[0] for w in data_tokens if w[1] == "NNP" and w[0] not in stopwords]

# %%
fd_names2=FreqDist(data_tokens2)

# %%
fd_names2.most_common(10)
# Out:
# [('Perrone', 21),
#  ('Arbe', 19),
#  ('Lightning', 13),
#  ('Level', 9),
#  ('AV', 9),
#  ('TONY', 8),
#  ('Hitzinger', 8),
#  ('Class', 7),
#  ('How', 6),
#  ('Forward', 6)]

# %%
import matplotlib .pyplot as plt
from wordcloud import WordCloud

# %%
wc = WordCloud(width=1000, height=600, background_color="white", random_state=0)
plt.imshow(wc.generate_from_frequencies(fd_names2))
plt.axis("off")
plt.show()
