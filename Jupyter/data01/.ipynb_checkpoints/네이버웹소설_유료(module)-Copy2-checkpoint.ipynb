# %%
from urllib import request
from bs4 import BeautifulSoup
import pandas as pd

# %%
class Doc:
    con = None
    doc = None
    img_list = []
    title_list = []
    author_list = []
    rating_list = []
    def con_doc(self, url):
        self.con = request.urlopen(url)
        self.con.status #status code
        self.doc = BeautifulSoup(self.con, 'html.parser')
    def crawl_img(self):
        img_crawl = doc.select('#content > div > div.ranking_lst > div.ranking_wrap_right > ul > li > a > div.pic > img')
    #     print(img_crawl)
        for crawl in img_crawl:
            self.img_list.append(crawl.get("src"))
    def crawl_title(self):
        title_crawl = doc.select('#content > div > div.ranking_lst > div.ranking_wrap_right > ul > li > a > div > p > span.tit')
        for title in title_crawl:
            self.title_list.append(title.text.replace(',',''))
    def crawl_author(self):
        author_crawl = doc.select('#content > div > div.ranking_lst > div.ranking_wrap_right > ul > li > a > div > p.sub_info > span.author')
        for author in author_crawl:
            self.author_list.append(author.text.replace(',',''))
    def crawl_rating(self):
        rating_lists=[]
        rating_crawl = doc.select('#content > div > div.ranking_lst > div.ranking_wrap_right > ul > li > a > div > p.rating > span.score_area')
        for ratings in rating_crawl:
            rating_lists.append(ratings.text)
        for s in rating_lists:
            self.rating_list.append(s[2:])
    def write_column(self):
        webtoon_file = open('webtoon.csv', 'w', encoding='utf8')
        webtoon_file.write('title' + ',' +
                         'author' + ',' +
                         'img'+','+'rating' +'\n')
        webtoon_file.close()

    def write_data(self):
        webtoon_file = open('webtoon.csv', 'a', encoding='utf8')
        for i in range(len(self.rating_list)):
            webtoon_file.write(self.title_list[i] + ',' + self.author_list[i] + ',' + self.img_list[i]+','+self.rating_list[i]+'\n')
        webtoon_file.close()
    def read_data(self):
            webtoonlist = pd.read_csv('webtoon.csv', encoding='utf8')
            return webtoonlist

# %%
doc1 = Doc()
url = 'https://novel.naver.com/best/ranking?genre=101&periodType=DAILY'
doc1.con_doc(url)
doc1.crawl_img()
doc1.crawl_rating()
doc1.crawl_title()
doc1.crawl_author()
doc1.write_column()
doc1.write_data()
webtoonlist = doc1.read_data()

# %%
webtoonlist
# Out:
#                              title         author  \
# 0                           위험한 오빠          달콤체리.
# 1                  피 흘리며 피는 꽃(개정판)            은밀희
# 2                   막내의 노예가 될 순 없어             금소
# 3                        바보에는 장사없다            은서노
# 4                       혼인신고부터 했어요            펀트리
# ...                            ...            ...
# 1195               선비님의 매니저가 되었습니다            세랑세
# 1196  나쁜남자 VS 착한 여자(개정판-착한여자 콤플렉스)      블 루 스 카 이
# 1197                             꽃  Winter flower
# 1198                       뱀파이어 탐정            초록반
# 1199                       두 번의 인연           정글피시
#
#                                                     img  rating
# 0     https://novel-phinf.pstatic.net/20220303_237/n...    10.0
# 1     https://novel-phinf.pstatic.net/20181022_116/n...    10.0
# 2     https://novel-phinf.pstatic.net/20220107_62/no...    10.0
# 3     https://novel-phinf.pstatic.net/20210111_147/n...    10.0
# 4     https://novel-phinf.pstatic.net/20200911_46/no...    10.0
# ...                                                 ...     ...
# 1195  https://novel-phinf.pstatic.net/20140404_280/n...     9.9
# 1196  https://novel-phinf.pstatic.net/20200715_266/n...     9.9
# 1197  https://novel-phinf.pstatic.net/20200325_268/n...    10.0
# 1198  https://novel-phinf.pstatic.net/20160705_194/n...    10.0
# 1199  https://novel-phinf.pstatic.net/20180105_251/n...     9.8
#
# [1200 rows x 4 columns]
