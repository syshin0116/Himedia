# %%
from urllib import request

# %%
from bs4 import BeautifulSoup

# %%
# !pip install bs4 #cmd에서 수행

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: AE94-D5A8
#
#  C:\Users\hi\Himedia_jupyter\data01 디렉터리
#
# 2022-03-15  오후 01:12    <DIR>          .
# 2022-03-15  오후 01:12    <DIR>          ..
# 2022-03-15  오후 12:38    <DIR>          .ipynb_checkpoints
# 2022-03-15  오후 12:57           163,975 crawling1.ipynb
# 2022-03-15  오후 01:12           229,183 crawling2.ipynb
# 2022-03-15  오전 11:58             2,372 test01.ipynb
# 2022-03-15  오전 11:56             1,145 test02.ipynb
#                4개 파일             396,675 바이트
#                3개 디렉터리  80,948,228,096 바이트 남음

# %%
# !ipconfig
# Out:
# Windows IP 구성
#
#
# 이더넷 어댑터 이더넷 4:
#
#    연결별 DNS 접미사. . . . :
#    링크-로컬 IPv6 주소 . . . . : fe80::b843:4da9:287e:4c07%10
#    IPv4 주소 . . . . . . . . . : 192.168.0.3
#    서브넷 마스크 . . . . . . . : 255.255.255.0
#    기본 게이트웨이 . . . . . . : 192.168.0.1

# %%
con = request.urlopen('https://kin.naver.com/')
con
#http response(header+body)
#header : http result status code(ok:200, not found:404, error: 500, permission: 403)

# %%
con.status #status code
# Out:
# 200

# %%
doc = BeautifulSoup(con, 'html.parser')
doc
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta contents="always" name="referrer"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="지식나눔과 기부로 함께 성장하는 지식iN을 만나보세요." name="description">
# <meta content="width=1024" name="viewport"/>
# <meta content="none" name="msapplication-config">
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220223140139/css/min/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220223140139/css/min/components.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220223140139/css/min/other.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220223140139/css/min/main.css" rel="stylesheet" type="text/css">
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220223140139/css/min/c3p.datalab.theme.css" rel="stylesheet" type="text/css"/>
# <script>
#
# ...

# %%
a_tag_list = doc.select("#au_lnb").select('a')
a_tag_list
# Out:
# []

# %%
type(a_tag_list)
# Out:
# list

# %%
#리스트의 개 수
len(a_tag_list)
# Out:
# 0

# %%
a_tag_list[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-625-a491c090ce82> in <module>
# ----> 1 a_tag_list[0]
#
# IndexError: list index out of range

# %%
a_tag_list[0].text

# %%
anav_list = []

# %%
for one in a_tag_list:
    anav_list.append(one.text)

# %%
anav_list
