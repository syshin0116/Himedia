# %%
import matplotlib

# %%
# !pip install matplotlib=버전

# %%
print(matplotlib.__version__)
# Out:
# 3.1.1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([1,2,3,4,5,6]) #1차원 
xpoints1 = np.array([1,2,3,4,5,6])
print(type(xpoints))
ypoints = np.array([100,50,30,20,10,100])
ypoints1 = np.array([10,20,30,70,30,10])
print(ypoints)
line1 = plt.plot(xpoints, ypoints, marker="^", linestyle='dotted')
line2 = plt.plot(xpoints1, ypoints1, marker="o")
plt.xlabel('number of students')
plt.ylabel('counts')
plt.legend(['term1', 'term2'])
plt.show()
# Out:
# <class 'numpy.ndarray'>
# [100  50  30  20  10 100]

# %%
import random

# %%
x = []
y = []
for i in range(100):
    x.append(random.randint(1,100))
    y.append(random.randint(1,100))
print(x[:10])
y[:10]
# Out:
# [57, 73, 71, 35, 19, 20, 92, 62, 63, 13]
# [72, 60, 31, 3, 58, 63, 22, 48, 19, 73]
