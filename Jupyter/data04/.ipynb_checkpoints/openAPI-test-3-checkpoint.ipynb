# %%
import requests

headers = {
    'accept': 'application/json',
    'Authorization': '1TanxHdS/5oT82LY6mFLABvV2vxxgnDfSMurOex4q4pDqMLbWSmajH8lolOLqqFKtLxfshqqC0BlSytwCL1KBA==',
}

params = (
    ('page', '1'),
    ('perPage', '1000'),
    ('serviceKey', '1TanxHdS/5oT82LY6mFLABvV2vxxgnDfSMurOex4q4pDqMLbWSmajH8lolOLqqFKtLxfshqqC0BlSytwCL1KBA=='),
)
url = 'https://api.odcloud.kr/api/15069309/v1/uddi:973ad0df-617a-4565-8e82-8ea7869e75d4'
## decode key가 적용되었음.
## api마다 연결이 되지 않는다고 한다면, encode, decode를 바꾸어 테스트해볼 것.
response = requests.get(url, headers=headers, params=params)
response
# Out:
# <Response [200]>

# %%
json_data = response.json()
json_data
# Out:
# {'currentCount': 10,
#  'data': [{'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '당직자공용 기자',
#    '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '헤럴드경제',
#    '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#    '일자': '2020-02-01',
#    '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#    '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#    '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#    '통합 분류1': '사회>의료_건강',
#    '통합 분류2': None,
#    '통합 분류3': None,
#    '특성추출': '신종코,추가,환자,확진'},
#   {'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '이상규',
#    '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '매일경제',
# ...

# %%
import pickle

# %%
with open('covid-gokr.json', 'wb') as fp:
    pickle.dump(json_data, fp)

# %%
with open('covid-gokr.json', 'rb') as fp:
    json_read_data = pickle.load(fp)
json_read_data
# Out:
# {'currentCount': 10,
#  'data': [{'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '당직자공용 기자',
#    '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '헤럴드경제',
#    '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#    '일자': '2020-02-01',
#    '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#    '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#    '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#    '통합 분류1': '사회>의료_건강',
#    '통합 분류2': None,
#    '통합 분류3': None,
#    '특성추출': '신종코,추가,환자,확진'},
#   {'개체명(기업기관)': None,
#    '개체명(인물)': None,
#    '개체명(지역)': None,
#    '기고자': '이상규',
#    '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#    '사건_사고 분류1': None,
#    '사건_사고 분류2': None,
#    '사건_사고 분류3': None,
#    '언론사': '매일경제',
# ...

# %%
json_data['currentCount']
# Out:
# 10

# %%
data_values = json_data.get('data')

# %%
addr = data_values[0]['원본주소']
addr
# Out:
# 'http://biz.heraldcorp.com/view.php?ud=20200201000027'

# %%
com = data_values[0]['언론사']
com
# Out:
# '헤럴드경제'

# %%
title = data_values[0]['제목']
title
# Out:
# "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어"

# %%
date = data_values[0]['일자']
date
# Out:
# '2020-02-01'

# %%
field =data_values[0]['통합 분류1']
field
# Out:
# '사회>의료_건강'

# %%
content =data_values[0]['본문']
content
# Out:
# "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews"

# %%
one_row = []
one_row.append(title)
one_row.append(content)
one_row.append(field)
one_row.append(date)
one_row.append(addr)
one_row.append(com)
one_row
# Out:
# ["[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#  "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#  '사회>의료_건강',
#  '2020-02-01',
#  'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#  '헤럴드경제']

# %%
total_rpw = []
for no in range(10):
    com = data_values[no]['언론사']
    addr = data_values[0]['원본주소']
    field =data_values[0]['통합분류1']
    date = data_values[0]['일자']
    title = data_values[0]['제목']
    content = data_values[0]['본문']
    one_row = []
    one_row.append(title)
    one_row.append(content)
    one_row.append(field)
    one_row.append(date)
    one_row.append(addr)
    one_row.append(com)
    print(one_row)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-e93ccee45f89> in <module>
#       3     com = data_values[no]['언론사']
#       4     addr = data_values[0]['원본주소']
# ----> 5     field =data_values[0]['통합분류1']
#       6     date = data_values[0]['일자']
#       7     title = data_values[0]['제목']
#
# KeyError: '통합분류1'

# %%
with open('covid-sub-data.json', 'wb') as fp:
    pickle.dump(total_row, fp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-9c0d2502b236> in <module>
#       1 with open('covid-sub-data.json', 'wb') as fp:
# ----> 2     pickle.dump(total_row, fp)
#
# NameError: name 'total_row' is not defined

# %%
with open('covid-sub-data.json', 'rb') as fp:
    json_sub_data = pickle.load(fp)
json_sub_data
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-92-fc6acaa88773> in <module>
#       1 with open('covid-sub-data.json', 'rb') as fp:
# ----> 2     json_sub_data = pickle.load(fp)
#       3 json_sub_data
#
# EOFError: Ran out of input

# %%
import pandas as pd
import numpy as np

# %%
with open('covid-sub-data-dic.json', 'wb') as fp:
    pickle.dump(data_values, fp)

# %%
with open('covid-sub-data-dic.json', 'rb') as fp:
    json_sub_data_dic = pickle.load(fp)
json_sub_data_dic
# Out:
# [{'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '당직자공용 기자',
#   '본문': "[헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 12명이 됐다.   onlinenews",
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '헤럴드경제',
#   '원본주소': 'http://biz.heraldcorp.com/view.php?ud=20200201000027',
#   '일자': '2020-02-01',
#   '제목': "[속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어",
#   '주소': 'http://www.bigkinds.or.kr/news/newsDetailView.do?newsId=02100701.20200201094636001',
#   '키워드': '신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명',
#   '통합 분류1': '사회>의료_건강',
#   '통합 분류2': None,
#   '통합 분류3': None,
#   '특성추출': '신종코,추가,환자,확진'},
#  {'개체명(기업기관)': None,
#   '개체명(인물)': None,
#   '개체명(지역)': None,
#   '기고자': '이상규',
#   '본문': '[속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털뉴스국 이상규 기자]',
#   '사건_사고 분류1': None,
#   '사건_사고 분류2': None,
#   '사건_사고 분류3': None,
#   '언론사': '매일경제',
#   '원본주소': 'http://news.mk.co.kr/newsRead.php?no=104142&year=2020',
#   '일자': '2020-02-01',
# ...

# %%
df_test = pd.DataFrame(json_sub_data_dic)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 18 columns):
# 개체명(기업기관)    0 non-null object
# 개체명(인물)      0 non-null object
# 개체명(지역)      0 non-null object
# 기고자          9 non-null object
# 본문           10 non-null object
# 사건_사고 분류1    0 non-null object
# 사건_사고 분류2    0 non-null object
# 사건_사고 분류3    0 non-null object
# 언론사          10 non-null object
# 원본주소         9 non-null object
# 일자           10 non-null object
# 제목           10 non-null object
# 주소           10 non-null object
# 키워드          10 non-null object
# 통합 분류1       10 non-null object
# 통합 분류2       0 non-null object
# 통합 분류3       0 non-null object
# 특성추출         10 non-null object
# dtypes: object(18)
# memory usage: 1.5+ KB

# %%
df_test.shape
# Out:
# (10, 18)

# %%
df_test.columns
# Out:
# Index(['개체명(기업기관)', '개체명(인물)', '개체명(지역)', '기고자', '본문', '사건_사고 분류1',
#        '사건_사고 분류2', '사건_사고 분류3', '언론사', '원본주소', '일자', '제목', '주소', '키워드',
#        '통합 분류1', '통합 분류2', '통합 분류3', '특성추출'],
#       dtype='object')

# %%
df_test.drop(columns=['개체명(기업기관)','개체명(인물)','개체명(지역)','사건_사고 분류1','사건_사고 분류2','사건_사고 분류3','통합 분류2','통합 분류3'], inplace = True)
df_test[:2]
# Out:
#         기고자                                                 본문    언론사  \
# 0  당직자공용 기자  [헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 1...  헤럴드경제
# 1       이상규  [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털...   매일경제
#
#                                                 원본주소          일자  \
# 0  http://biz.heraldcorp.com/view.php?ud=20200201...  2020-02-01
# 1  http://news.mk.co.kr/newsRead.php?no=104142&ye...  2020-02-01
#
#                                           제목  \
# 0           [속보] '신종코로나' 확진환자 1명 추가…12명으로 늘어
# 1  [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시
#
#                                                   주소  \
# 0  http://www.bigkinds.or.kr/news/newsDetailView....
# 1  http://www.bigkinds.or.kr/news/newsDetailView....
#
#                                             키워드    통합 분류1                 특성추출
# 0          신종코,추가,확진,환자,12명,신종코,추가,확진,환자,확진,12명  사회>의료_건강         신종코,추가,환자,확진
# 1  신종코,확진,70명,검사,접촉자,감시,속보,신종코,확진,70명,검사,접촉자,감시  사회>의료_건강  접촉자,신종코,감시,확진,검사,속보

# %%
df_test['기고자'][:2]
# Out:
# 0    당직자공용 기자
# 1         이상규
# Name: 기고자, dtype: object

# %%
df_test['본문']
# Out:
# 0    [헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 1...
# 1    [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털...
# 2    [그래픽=연합뉴스]  신종 코로나바이러스 확진자가 1일 오후 2시 현재 총 12명으...
# 3    [속보] '신종코로나' 확진환자…1명 추가 국내 총 12명   이미경 한경닷컴 기자...
# 4                          '신종코로나' 확진환자 1명 추가…국내 총 12명
# 5        [헤럴드경제] 신종코로나 국내 12명 확진·70명은 검사 중…접촉자 465명 감시
# 6     [속보] '신종코로나' 확진환자 1명 추가…국내 총 12명 [디지털뉴스국 이상규 기자]
# 7    ◀ 앵커 ..▶ .. ..국내에서 2차 감염에 이어 3차 감염자까지 나오면서 확진자...
# 8                         [아시아경제 조현의 기자]  조현의 기자 honey
# 9                 '신종 코로나바이러스 감염증’ 확진환자 3명 추가…국내 총 15명
# Name: 본문, dtype: object

# %%
df_test.to_csv('covid_news.csv', encoding='utf8')

# %%
df_test2 = pd.read_csv('covid_news.csv', encoding='utf8')
df_test2
# Out:
#    Unnamed: 0            기고자  \
# 0           0       당직자공용 기자
# 1           1            이상규
# 2           2            황재희
# 3           3  이미경(capital);
# 4           4            김봄이
# 5           5        이정환2 기자
# 6           6            이상규
# 7           7            전동혁
# 8           8            조현의
# 9           9            NaN
#
#                                                   본문    언론사  \
# 0  [헤럴드경제] '신종코로나' 확진환자 1명 추가됐다. 이로써 국내 확진환자는 총 1...  헤럴드경제
# 1  [속보] 신종코로나 국내 12명 확진·70명 검사 중…접촉자 465명 감시 [디지털...   매일경제
# 2  [그래픽=연합뉴스]  신종 코로나바이러스 확진자가 1일 오후 2시 현재 총 12명으...   아주경제
# 3  [속보] '신종코로나' 확진환자…1명 추가 국내 총 12명   이미경 한경닷컴 기자...   한국경제
# 4                        '신종코로나' 확진환자 1명 추가…국내 총 12명   매일신문
# 5      [헤럴드경제] 신종코로나 국내 12명 확진·70명은 검사 중…접촉자 465명 감시  헤럴드경제
# 6   [속보] '신종코로나' 확진환자 1명 추가…국내 총 12명 [디지털뉴스국 이상규 기자]   매일경제
# 7  ◀ 앵커 ..▶ .. ..국내에서 2차 감염에 이어 3차 감염자까지 나오면서 확진자...    MBC
# 8                       [아시아경제 조현의 기자]  조현의 기자 honey  아시아경제
# ...
