# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import datetime
import time
import json
client_id = 'XmAPiOuFA_rJ7TcZTHK0'
client_secret = '86fJUY5PW8'
def getRequestUrl(url):
    req = urllib.request.Request(url)
    req.add_header("X-Naver-Client-Id", client_id)
    req.add_header("X-Naver-Client-Secret", client_secret)

    try:
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None
        
        
def getNaverSearch(node, srcText, page_start, display):
    base = "https://openapi.naver.com/v1/search"
    node = "/%s.json" % node
    parameters = "?query=%s&start=%s&display=%s" % (urllib.parse.quote(srcText), page_start, display)

    url = base + node + parameters
    responseDecode = getRequestUrl(url) #[CODE 1]

    if (responseDecode == None):
        return None
    else:
        return json.loads(responseDecode)
    
def getPostData(post, jsonResult, cnt):
    title = post['title']
    description = post['description']
    bloggername = post['bloggername']
    bloggerlink = post['bloggerlink']

#     pDate = datetime.datetime
#     .strptime(post['postdate'],'%Y%m%d')
#     pDate = pDate.strftime('%Y%m%d')

    jsonResult.append({'cnt':cnt, 'title':title, 'description': description, 'bloggername':bloggername, 'bloggerlink': bloggerlink})
    return
def main():
    node = 'blog' #크롤링할 대상
    srcText = input('검색어를 입력하세요:')
    cnt = 0
    jsonResult = []
    jsonResponse = getNaverSearch(node, srcText, 1, 100) #[CODE 2]
    total = jsonResponse['total']
    while ((jsonResponse != None) and (jsonResponse['display'] != 0)):
        for post in jsonResponse['items']:
                                 cnt += 1
                                 getPostData(post, jsonResult, cnt) #[CODE 3]

    start = jsonResponse['start'] + jsonResponse['display']
    jsonResponse = getNaverSearch(node, srcText, start, 100) #[CODE 2]

    print('전체 검색 : %d 건' %total)

    with open('%s_naver_%s.json' % (srcText, node), 'w', encoding='utf8') as outfile:
              jsonFile = json.dumps(jsonResult, indent = 4, sort_keys = True, ensure_ascii = False)
              outfile.write(jsonFile)

    print("가져온 데이터 : %d 건" %(cnt))
    print('%s_naver_%s.json SAVED' % (srcText, node))

# %%
main()

# %%
import os
import sys
import urllib.request
client_id = "XmAPiOuFA_rJ7TcZTHK0"
client_secret = "86fJUY5PW8"
encText = urllib.parse.quote("맛집")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 22 Mar 2022 10:00:36 +0900",
# "total": 39467297,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "인테리어도 고급진 제주 안돌오름 <b>맛집</b>",
# "link": "https:\/\/blog.naver.com\/oyjj7975?Redirect=Log&logNo=222675406877",
# "description": "몇 주 전에는 아는 지인과 함께 제주 여행 도중에 친구의 추천으로 제주 안돌오름 <b>맛집</b>을 방문했는데요.... 안전히 주차를 마치고 제주 안돌오름 <b>맛집</b> 실내로 들어가 보니 내부는 무척 깔끔하고 쾌적하게... ",
# "bloggername": "아뜰리에봄",
# "bloggerlink": "https://blog.naver.com/oyjj7975",
# "postdate": "20220318"
#
# },
# {
# "title": "든든했던 청주 산남동 <b>맛집</b>",
# "link": "https:\/\/blog.naver.com\/5791234?Redirect=Log&logNo=222674381269",
# "description": "부담이 덜 가면서 든든한 음식을 먹고 싶었던 터라 청주 산남동 <b>맛집</b>을 다녀오게 됐어요. 저희가 간... 전체적으로 청주 산남동 <b>맛집</b> 내부는 운영이 깔끔하게 잘 이루어지고 있어서 마음에 쏙! 들었어요. 반찬은... ",
# "bloggername": "༼ つ ◕_◕ ༽つ",
# "bloggerlink": "https://blog.naver.com/5791234",
# "postdate": "20220316"
#
# },
# {
# "title": "인정하는 배곧 <b>맛집</b>",
# "link": "https:\/\/blog.naver.com\/sopung_gab?Redirect=Log&logNo=222674620922",
# "description": "지난 주말 친구들과 허한 몸을 충전하기 위해 유명하다는 배곧 <b>맛집</b>에 찾아갔어요. 신선한 장어를 가성비 좋게 즐길 수 있어 만족스러운 시간을 보냈던 곳이라 소개해드립니다. #배곧<b>맛집</b> #100년장어촌... ",
# "bloggername": "소풍갑니다",
# "bloggerlink": "https://blog.naver.com/sopung_gab",
# "postdate": "20220316"
#
# },
# {
# "title": "반해버렸던 안면도 <b>맛집</b>",
# "link": "https:\/\/blog.naver.com\/wooandsu?Redirect=Log&logNo=222672407811",
# "description": "반해버렸던 안면도 <b>맛집</b> 친구들과 꽃지해변에 바다 만끽하러 다녀 오는 길에 안면도 <b>맛집</b>에 방문을 했어요. 안면도에서 제철에 직접 공수한 꽃게에 송화가루를 더해 조리한 간장게장과 게국지의 뛰어난... ",
# "bloggername": "Everyday Everything",
# "bloggerlink": "https://blog.naver.com/wooandsu",
# "postdate": "20220315"
#
# },
# {
# "title": "황홀했던 인천 연안부두 <b>맛집</b>",
# "link": "https:\/\/blog.naver.com\/jamie73?Redirect=Log&logNo=222668940299",
# "description": "얼마전 인천항으로 바닷바람 쐬러 갔다가 현지분들이 극찬하시는 인천 연안부두 <b>맛집</b>에 들렀어요.... 인천 연안부두 <b>맛집</b>에서는 크게 회와 갑각류로 나뉘어져 있었는데, 저희는 사장님께서 강추해주신... ",
# "bloggername": "고독한 대식가",
# "bloggerlink": "https://blog.naver.com/jamie73",
# "postdate": "20220310"
#
# },
# {
# "title": "엄청났던 제주 머체왓숲길 <b>맛집</b>",
# "link": "https:\/\/blog.naver.com\/moamoasa?Redirect=Log&logNo=222673326270",
# "description": "지난주에 3일 정도 일정을 잡고 여행 온 친구와 함께 제주 머체왓숲길 <b>맛집</b>을 다녀왔어요. 오랜... 주차를 마치고 제주 머체왓숲길 <b>맛집</b> 실내로 입장해 보았는데요. 깔끔하게 정리되어 있어 마음에 들더라고요.... ",
# "bloggername": "배부른솔미",
# "bloggerlink": "https://blog.naver.com/moamoasa",
# "postdate": "20220316"
#
# },
# {
# "title": "죽도시장 포항 물회 <b>맛집</b>",
# "link": "https:\/\/blog.naver.com\/csimple?Redirect=Log&logNo=222668912431",
# "description": "최근에 동생들과 영일대해수욕장에 놀러 갔다가 입소문 난 포항 물회 <b>맛집</b>에 방문했습니다. 저렴한... 여러 가지 생선 요리가 적혀있었는데 저희는 포항 물회 <b>맛집</b>의 인기메뉴인 모듬 회와 대게찜을 4인분... ",
# "bloggername": "CSIMPLE BLOG",
# "bloggerlink": "https://blog.naver.com/csimple",
# "postdate": "20220310"
#
# },
# {
# "title": "특별한 횟집 목포 북항 <b>맛집</b>",
# "link": "https:\/\/blog.naver.com\/cuo07?Redirect=Log&logNo=222677151112",
# "description": "가기 전부터 미리 찾아 두었던 목포 북항 <b>맛집</b>을 갔는데 싱싱한 해산물을 배터지게 먹을 수 있는 집이라... 목포 북항 <b>맛집</b>에는 유아용 의자도 전부 준비되어 있었는데 더러움 없이 정말 깔끔했어요. 가게는 거의... ",
# "bloggername": "NINANO",
# "bloggerlink": "https://blog.naver.com/cuo07",
# "postdate": "20220319"
#
# },
# {
# "title": "매력 터지는 한남동 <b>맛집</b>",
# "link": "https:\/\/blog.naver.com\/trans9876?Redirect=Log&logNo=222669184796",
# "description": "며칠전 용산에 사는 친구들과 저녁 모임도 할 겸 SNS에서 모르는 사람이 없다는 한남동 <b>맛집</b>에... 한남동 <b>맛집</b>에서는 크게 비프와 디너류로 나뉘어져 있었는데, 저희는 이곳의 시그니처라는 숙성꽃등심(69,000원)... ",
# "bloggername": "프로 레슬링 광장",
# "bloggerlink": "https://blog.naver.com/trans9876",
# "postdate": "20220310"
#
# },
# {
# "title": "대만족했던 제주 애월 <b>맛집</b>",
# "link": "https:\/\/blog.naver.com\/i_holmesian?Redirect=Log&logNo=222668954682",
# "description": "지난번 제주여행 중 몸보신을 하기 위해 제주 애월 <b>맛집</b>에 찾아갔어요. 도톰한 흑돈은 남다른 육즙을... 제주 애월 <b>맛집</b> 영업시간은 오전 10시부터 저녁 12시까지 연중무휴로 운영된다고 해요. 서둘러 안으로... ",
# "bloggername": "소소한 일상을 기록하는 공간",
# "bloggerlink": "https://blog.naver.com/i_holmesian",
# "postdate": "20220311"
#
# }
# ]
# }

# %%
import requests
import time
from urllib.parse import quote
import pandas as pd
import urllib.request


client_id = 'qifMbSmo_iuDeai3dkwT'
client_secret = 'qybg03_lrU'
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}


url_base="https://openapi.naver.com/v1/search/blog.json?query="
keyword = quote(input("검색 키워드를 입력하세요. : "))
keyword_number=input("몇 번째부터 검색할까요? : ")
display=input("몇 개까지 검색할까요? : ")


parameters = "?query = %s&start=%s&display=%s" %(urllib.parse.quote(keyword), keyword_number, display)
url = url_base + parameters
print(url)
result = requests.get(url,headers = headers).json()                  #결과값을 변수로 지정
result
